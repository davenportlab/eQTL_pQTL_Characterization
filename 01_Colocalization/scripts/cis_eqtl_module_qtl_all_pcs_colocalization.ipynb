# %% [markdown]
# # Cis-eQTL Module QTL All PCs Colocalization
#
# **Created**: 20 May 2022

# %% [markdown]
# ## Environment

# %%
library(tidyverse)
library(data.table)
library(coloc)
library(GenomicRanges)

setwd("~/eQTL_pQTL_Characterization/")

source("01_Colocalization/scripts/utils/ggplot_theme.R")
# Out:
# Warning message in system("timedatectl", intern = TRUE):
# “running command 'timedatectl' had status 1”
# ── Attaching packages ───────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────── tidyverse 1.3.1 ──
#
# ✔ ggplot2 3.3.5     ✔ purrr   0.3.4
# ✔ tibble  3.1.6     ✔ dplyr   1.0.8
# ✔ tidyr   1.2.0     ✔ stringr 1.4.0
# ✔ readr   2.1.1     ✔ forcats 0.5.1
#
# ── Conflicts ──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
#
#
# Attaching package: ‘data.table’
#
#
# The following objects are masked from ‘package:dplyr’:
#
#     between, first, last
#
#
# The following object is masked from ‘package:purrr’:
#
#     transpose
#
#
# This is coloc version 5.1.1
#
# Loading required package: stats4
#
# Loading required package: BiocGenerics
#
# Loading required package: parallel
#
#
# Attaching package: ‘BiocGenerics’
#
#
# The following objects are masked from ‘package:parallel’:
#
#     clusterApply, clusterApplyLB, clusterCall, clusterEvalQ,
#     clusterExport, clusterMap, parApply, parCapply, parLapply,
#     parLapplyLB, parRapply, parSapply, parSapplyLB
#
#
# The following objects are masked from ‘package:dplyr’:
#
#     combine, intersect, setdiff, union
#
#
# The following objects are masked from ‘package:stats’:
#
#     IQR, mad, sd, var, xtabs
#
#
# The following objects are masked from ‘package:base’:
#
#     anyDuplicated, append, as.data.frame, basename, cbind, colnames,
#     dirname, do.call, duplicated, eval, evalq, Filter, Find, get, grep,
#     grepl, intersect, is.unsorted, lapply, Map, mapply, match, mget,
#     order, paste, pmax, pmax.int, pmin, pmin.int, Position, rank,
#     rbind, Reduce, rownames, sapply, setdiff, sort, table, tapply,
#     union, unique, unsplit, which.max, which.min
#
#
# Loading required package: S4Vectors
#
#
# Attaching package: ‘S4Vectors’
#
#
# The following objects are masked from ‘package:data.table’:
#
#     first, second
#
#
# The following objects are masked from ‘package:dplyr’:
#
#     first, rename
#
#
# The following object is masked from ‘package:tidyr’:
#
#     expand
#
#
# The following object is masked from ‘package:base’:
#
#     expand.grid
#
#
# Loading required package: IRanges
#
#
# Attaching package: ‘IRanges’
#
#
# The following object is masked from ‘package:data.table’:
#
#     shift
#
#
# The following objects are masked from ‘package:dplyr’:
#
#     collapse, desc, slice
#
#
# The following object is masked from ‘package:purrr’:
#
#     reduce
#
#
# Loading required package: GenomeInfoDb

# %% [markdown]
# ## Load Summary Information

# %% [markdown]
# Load summary statistics from conditional analysis performed using COJO. Only use cis-eQTL that have the same lead eSNP.

# %%
geno.bim <- fread("/nfs/users/nfs_n/nm18/gains_team282/Genotyping/All_genotyping_merged_filtered_b38_refiltered_rsID.bim")

colnames(geno.bim) <- c("chr", "snp", "cM", "pos", "minor_allele", "major_allele")

# %%
head(geno.bim)
# Out:
#   chr snp          cM pos    minor_allele major_allele
# 1 1   rs3131972    0  817341 A            G
# 2 1   rs546843995  0  818053 0            G
# 3 1   rs553916047  0  818359 0            A
# 4 1   1:818740_T_C 0  818740 T            C
# 5 1   rs145604921  0  819378 0            C
# 6 1   rs535256652  0  821053 0            T

# %%
module.ss.dir = "/nfs/users/nfs_n/nm18/gains_team282/nikhil/expression/eigengene_sva/wgcna_summary_statistics/"
module.qtl <- do.call(rbind, lapply(list.files(module.ss.dir, pattern="ME_[0-9]+_[0-9]+-.*\\.tsv"), function(file.name) {

    fread(paste0(module.ss.dir, file.name)) %>%
    as.data.frame() %>%
    dplyr::select(snp=1, beta=2, se=3, t=4, p=5) %>%
    dplyr::mutate(module.qtl=gsub("\\.tsv", "", file.name)) %>%
    dplyr::mutate(module=gsub("_[0-9]+-.*$", "", module.qtl)) %>%
    dplyr::mutate(pc=gsub("-.*$", "", gsub("ME_[0-9]+_", "", module.qtl))) %>%
    dplyr::mutate(qtl.locus=gsub("ME_[0-9]+_[0-9]+-", "", module.qtl)) %>%
    dplyr::mutate(qtl.locus.chr=gsub("\\:.*", "", qtl.locus)) %>%
    dplyr::mutate(qtl.locus.start=as.numeric(gsub(".*\\:", "", gsub("-.*$", "", qtl.locus)))) %>%
    dplyr::mutate(qtl.locus.end=as.numeric(gsub(".*-", "", qtl.locus)))
})) %>%
    merge(., geno.bim, by="snp")

# %%
head(module.qtl)
# Out:
#   snp        beta          se          t          p
# 1 rs10000031 -0.0015209496 0.002643137 -0.5754335 0.5652229
# 2 rs10000031  0.0026582878 0.002491213  1.0670656 0.2864698
# 3 rs10000031  0.0015223970 0.001190428  1.2788649 0.2012264
# 4 rs10000031  0.0003156089 0.002492007  0.1266485 0.8992224
# 5 rs10000031  0.0009403553 0.002550184  0.3687402 0.7123997
# 6 rs10000051  0.0005686373 0.001916458  0.2967127 0.7666921
#   module.qtl                    module pc qtl.locus             qtl.locus.chr
# 1 ME_87_5-4:67472593-69475768   ME_87  5  4:67472593-69475768   4
# 2 ME_87_4-4:67472593-69475768   ME_87  4  4:67472593-69475768   4
# 3 ME_87_1-4:67472593-69475768   ME_87  1  4:67472593-69475768   4
# 4 ME_87_2-4:67472593-69475768   ME_87  2  4:67472593-69475768   4
# 5 ME_87_3-4:67472593-69475768   ME_87  3  4:67472593-69475768   4
# 6 ME_86_3-4:117564190-120834939 ME_86  3  4:117564190-120834939 4
#   qtl.locus.start qtl.locus.end chr cM pos       minor_allele major_allele
# 1  67472593        69475768     4   0   68683231 G            A
# 2  67472593        69475768     4   0   68683231 G            A
# 3  67472593        69475768     4   0   68683231 G            A
# 4  67472593        69475768     4   0   68683231 G            A
# 5  67472593        69475768     4   0   68683231 G            A
# 6 117564190       120834939     4   0  120370537 T            C

# %% [markdown]
# ## Load Gene Expression and Module Eigengenes

# %%
gene.exp <- read.table("/lustre/scratch119/humgen/projects/gains_team282/eqtl/data/logcpm_864_20412_hla.txt")
gene.exp <- t(gene.exp)
rownames(gene.exp) <- gsub("^GA", "", rownames(gene.exp))

# %%
head(gene.exp)
# Out:
#              ENSG00000230521 ENSG00000225864 ENSG00000227766 ENSG00000237669
# UK02270173_3 0.6644339       0.9817872       1.2117156       0.6420763
# UK15130120_3 0.5827160       0.4387994       0.3068267       0.6925683
# UK58000006_3 0.4046756       0.6022344       0.6625010       0.9792012
# UK47010004_3 0.2090516       0.9234049       0.7996329       0.6992958
# UK42020088_5 0.2211571       0.2211571       0.6445686       0.3765156
# UK47490007_3 0.4288519       1.1450686       0.3130290       1.0756817
#              ENSG00000271581 ENSG00000285647 ENSG00000204435 ENSG00000231074
# UK02270173_3 2.474490        0.00000000      3.704888        4.027339
# UK15130120_3 1.331531        0.03379072      4.261280        3.634898
# UK58000006_3 1.831046        0.00000000      3.719682        3.597655
# UK47010004_3 2.475317        0.05517067      4.169617        3.016982
# UK42020088_5 1.881204        0.67482702      4.527758        3.624300
# UK47490007_3 2.053137        0.00000000      4.581986        3.101136
#              ENSG00000227262 ENSG00000206337 ⋯ ENSG00000288253 ENSG00000288302
# UK02270173_3 0.06866465      7.318038        ⋯ 0.5247755       1.3000450
# UK15130120_3 0.25046090      6.369198        ⋯ 0.5125515       1.7424980
# UK58000006_3 0.00000000      6.837021        ⋯ 0.2947282       1.5250610
# UK47010004_3 0.30321616      7.723203        ⋯ 0.3032162       0.9527571
# UK42020088_5 0.04702687      6.350747        ⋯ 0.0925691       1.2174450
# UK47490007_3 0.00000000      6.728267        ⋯ 0.5012039       1.9916780
#              ENSG00000288349 ENSG00000288393 ENSG00000288398 ENSG00000288538
# UK02270173_3 0.5247755       0.92735960      1.133738        1.1337380
# UK15130120_3 0.4883840       0.06680807      1.860177        0.6496258
# UK58000006_3 0.6326824       0.66250100      1.315821        1.4755270
# UK47010004_3 1.0911770       0.30321620      1.143029        1.8370600
# UK42020088_5 0.6748270       0.13671760      1.088510        2.0637890
# UK47490007_3 1.1895390       0.35267880      1.211271        0.7590055
#              ENSG00000288559 ENSG00000288562 ENSG00000288573 ENSG00000288582
# UK02270173_3 0.9457312       0.87079780      0.31467050      2.811486
# UK15130120_3 0.9264084       0.06680807      0.22143010      3.343063
# UK58000006_3 1.0258310       0.29472820      0.13374420      4.010874
# UK47010004_3 0.7669565       0.25690200      0.10830900      2.610379
# UK42020088_5 0.8172741       0.04702687      0.22115710      2.434768
# UK47490007_3 0.6033524       1.02749800      0.09657541      3.816079

# %%
eigengenes <- read.csv("~/gains_team282/nikhil/expression/gene_expression/eigengenes.multiple.csv", row.names=1)

# %%
head(eigengenes)
# Out:
#              ME_1_1       ME_1_2      ME_1_3       ME_1_4       ME_1_5
# UK02270173_3  0.008640296 -0.04165815  0.027430556 -0.020437463  0.018138657
# UK15130120_3 -0.037073495 -0.01795641 -0.007283072 -0.026494085  0.003339612
# UK58000006_3  0.029670524 -0.03481715  0.028491140 -0.009483861 -0.005862293
# UK47010004_3  0.011954974  0.01091971  0.038665347  0.003726632  0.052019153
# UK42020088_5  0.009818957  0.02100233 -0.019852180 -0.013052613 -0.030223051
# UK47490007_3 -0.021930377  0.03807246  0.042329128 -0.025160071  0.012732846
#              ME_2_1       ME_2_2      ME_2_3      ME_2_4       ME_2_5       ⋯
# UK02270173_3  0.007926439 -0.03881513  0.03058366 -0.014329184  0.009126178 ⋯
# UK15130120_3 -0.033179470 -0.01991901 -0.01688432 -0.014852805  0.049310271 ⋯
# UK58000006_3  0.021490110 -0.03480085  0.03014656 -0.003961906 -0.032946862 ⋯
# UK47010004_3  0.007360515  0.01763746  0.03490663 -0.005573984 -0.016190548 ⋯
# UK42020088_5  0.008322535  0.01712902 -0.02394729  0.003193689  0.019716419 ⋯
# UK47490007_3 -0.024756322  0.03899339  0.03987212 -0.030754242  0.038550679 ⋯
#              ME_105_1     ME_105_2     ME_105_3     ME_105_4      ME_105_5
# UK02270173_3  0.033258706  0.010337824  0.031572946  0.0308363822 -0.01556043
# UK15130120_3  0.051184001 -0.001611603  0.005624913  0.0273538940 -0.03670228
# UK58000006_3 -0.006622840 -0.045791646  0.033491934 -0.0420056572  0.02749077
# UK47010004_3 -0.003072117 -0.010005728  0.019263388  0.0009626484  0.06116524
# UK42020088_5 -0.032697222 -0.001257679 -0.019760950 -0.0079000979  0.02988006
# UK47490007_3 -0.003607270  0.043079589  0.025888343  0.0413386960  0.04360340
#              ME_106_1     ME_106_2    ME_106_3     ME_106_4     ME_106_5
# UK02270173_3 -0.003317747  0.01850385  0.001776021  0.034254655  0.002439359
# UK15130120_3 -0.012327128  0.04405671  0.013144923  0.017987682 -0.001779326
# UK58000006_3 -0.004740631  0.04638229 -0.043309799  0.028730908 -0.024051766
# UK47010004_3  0.012014706  0.01637633 -0.003045472 -0.018223178 -0.020637855
# UK42020088_5  0.007915598 -0.01649680  0.013250580 -0.031445321 -0.014168970
# UK47490007_3  0.024871961 -0.03349057  0.029665102 -0.009251542 -0.052908888

# %% [markdown]
# ## Generate Module and cis-eQTL Intervals

# %% [markdown]
# Not all PCs will have a significant association. Restrict to module-PC pairs that have a significant association.

# %%
n.modules <- ncol(eigengenes)

# %%
n.snps = system("head -n 1 /nfs/users/nfs_n/nm18/gains_team282/nikhil/data/genotypes/eigengene_sva_genotypes.raw | sed 's/ /\\n/g' | wc -l", intern=TRUE)
n.snps = as.numeric(n.snps) - 6

# %%
module.qtl.to.test <- module.qtl %>%
    dplyr::group_by(module.qtl) %>%
    dplyr::summarize(min.p = min(p)) %>%
    dplyr::filter(min.p < 0.05 / (n.modules * n.snps))

module.qtl <- module.qtl %>%
    dplyr::filter(module.qtl %in% module.qtl.to.test$module.qtl)

# %%
head(module.qtl)
# Out:
#   snp        beta          se          t          p
# 1 rs10000031  0.0009403553 0.002550184  0.3687402 0.71239971
# 2 rs10000051  0.0005686373 0.001916458  0.2967127 0.76669210
# 3 rs10000051 -0.0016456288 0.001713202 -0.9605575 0.33691166
# 4 rs10000051 -0.0008872361 0.001516617 -0.5850101 0.55886670
# 5 rs10000051  0.0025336374 0.001212417  2.0897402 0.03691116
# 6 rs10000051 -0.0022499130 0.001630515 -1.3798789 0.16788022
#   module.qtl                    module pc qtl.locus             qtl.locus.chr
# 1 ME_87_3-4:67472593-69475768   ME_87  3  4:67472593-69475768   4
# 2 ME_86_3-4:117564190-120834939 ME_86  3  4:117564190-120834939 4
# 3 ME_86_5-4:117564190-120834939 ME_86  5  4:117564190-120834939 4
# 4 ME_86_4-4:117564190-120834939 ME_86  4  4:117564190-120834939 4
# 5 ME_86_1-4:117564190-120834939 ME_86  1  4:117564190-120834939 4
# 6 ME_86_2-4:117564190-120834939 ME_86  2  4:117564190-120834939 4
#   qtl.locus.start qtl.locus.end chr cM pos       minor_allele major_allele
# 1  67472593        69475768     4   0   68683231 G            A
# 2 117564190       120834939     4   0  120370537 T            C
# 3 117564190       120834939     4   0  120370537 T            C
# 4 117564190       120834939     4   0  120370537 T            C
# 5 117564190       120834939     4   0  120370537 T            C
# 6 117564190       120834939     4   0  120370537 T            C

# %%
module.qtl.ranges <- module.qtl %>%
    dplyr::select(chr=qtl.locus.chr, start=qtl.locus.start, end=qtl.locus.end, qtl.locus) %>%
    unique() %>%
    makeGRangesFromDataFrame(keep.extra.columns=TRUE)

# %%
cis.eqtl.summary <- do.call(rbind, lapply(unique(module.qtl$qtl.locus.chr), function(chr) {
    eqtl.ss = fread(paste0("/nfs/users/nfs_n/nm18/gains_team282/nikhil/colocalization/cis_eqtl/conditional_effects/LD/chr", chr, "_conditional_cis_eQTL_summary_statistics.tsv")) %>%
        as.data.frame() %>%
        dplyr::mutate(ID=paste0(Gene, "-", Signal))
    
    eqtl.ss.ranges = eqtl.ss %>%
        makeGRangesFromDataFrame(seqnames.field="Chr", start.field="Position", end.field="Position", keep.extra.columns=TRUE)
    
    overlaps = findOverlaps(eqtl.ss.ranges, module.qtl.ranges)
    
    result = eqtl.ss[overlaps@from, ]
    result$QTL.Locus = mcols(module.qtl.ranges)$qtl.locus[overlaps@to]
    
    return(result)
}))

# %%
head(cis.eqtl.summary)
# Out:
#     Gene            Signal Chr SNP        Position Beta        SE
# 44  ENSG00000002549 1      4   rs10017860 16593256 0.019201257 0.03151489
# 64  ENSG00000002549 1      4   rs10023986 16644735 0.042116682 0.04129068
# 73  ENSG00000002549 1      4   rs10026224 16617798 0.036637176 0.02416366
# 84  ENSG00000002549 1      4   rs10030983 16606705 0.002486118 0.08230272
# 110 ENSG00000002549 1      4   rs1027784  16664709 0.002332156 0.02472518
# 151 ENSG00000002549 1      4   rs10939675 16608964 0.027776598 0.02340553
#     P_Value   ID                QTL.Locus
# 44  0.5423901 ENSG00000002549-1 4:14564113-16671474
# 64  0.3079045 ENSG00000002549-1 4:14564113-16671474
# 73  0.1298959 ENSG00000002549-1 4:14564113-16671474
# 84  0.9759090 ENSG00000002549-1 4:14564113-16671474
# 110 0.9248528 ENSG00000002549-1 4:14564113-16671474
# 151 0.2356246 ENSG00000002549-1 4:14564113-16671474

# %% [markdown]
# Split summary statistics by locus.

# %%
cis.eqtl.loci <- split(cis.eqtl.summary, cis.eqtl.summary$QTL.Locus) %>%
    lapply(., function(x) { split(x, x$ID) })

# %%
module.qtl.loci <- split(module.qtl, module.qtl$qtl.locus) %>%
    lapply(., function(x) { split(x, x$module.qtl) })

# %% [markdown]
# ## COLOC

# %%
coloc.res <- do.call(rbind, lapply(names(module.qtl.loci), function(qtl.locus) {

    do.call(rbind, lapply(names(module.qtl.loci[[qtl.locus]]), function(module.qtl.id) {

        do.call(rbind, lapply(names(cis.eqtl.loci[[qtl.locus]]), function(cis.eqtl.id) {

            cis.eqtl.loci[[qtl.locus]][[cis.eqtl.id]] <- cis.eqtl.loci[[qtl.locus]][[cis.eqtl.id]] %>%
                dplyr::filter(!is.na(Beta))

            gene = gsub("-.*", "", cis.eqtl.id)
            me = gsub("-.*", "", module.qtl.id)

            cis.eqtl <- list()
            cis.eqtl$beta <- cis.eqtl.loci[[qtl.locus]][[cis.eqtl.id]]$Beta
            cis.eqtl$varbeta <- cis.eqtl.loci[[qtl.locus]][[cis.eqtl.id]]$SE^2
            cis.eqtl$snp <- cis.eqtl.loci[[qtl.locus]][[cis.eqtl.id]]$SNP
            cis.eqtl$position <- cis.eqtl.loci[[qtl.locus]][[cis.eqtl.id]]$Position
            cis.eqtl$type <- "quant"
            cis.eqtl$sdY <- sd(gene.exp[, gene], na.rm=TRUE)

            module.qtl <- list()
            module.qtl$beta <- module.qtl.loci[[qtl.locus]][[module.qtl.id]]$beta
            module.qtl$varbeta <- module.qtl.loci[[qtl.locus]][[module.qtl.id]]$se^2
            module.qtl$snp <- module.qtl.loci[[qtl.locus]][[module.qtl.id]]$snp
            module.qtl$position <- module.qtl.loci[[qtl.locus]][[module.qtl.id]]$pos
            module.qtl$type <- "quant"
            module.qtl$sdY <- sd(eigengenes[, me], na.rm=TRUE)

            abf.res = suppressWarnings(coloc.abf(cis.eqtl, module.qtl))

            abf.res.df = data.frame(t(abf.res$summary))
            abf.res.df$Gene = gene
            abf.res.df$eQTL.Signal = gsub(".*-", "", cis.eqtl.id)
            abf.res.df$Eigengene = me
            abf.res.df$Module.QTL = module.qtl.id

            return(abf.res.df)
        }))
    }))
}))
# Out:
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#  1.06e-27  1.40e-09  1.70e-19  2.25e-01  7.75e-01
# [1] "PP abf for shared variant: 77.5%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#  3.47e-13  6.29e-09  5.52e-05  1.00e+00  1.54e-05
# [1] "PP abf for shared variant: 0.00154%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#  5.28e-09  7.31e-10  8.40e-01  1.16e-01  4.42e-02
# [1] "PP abf for shared variant: 4.42%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#  0.947000  0.039300  0.012200  0.000505  0.001170
# [1] "PP abf for shared variant: 0.117%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#  0.967000  0.019400  0.012500  0.000249  0.000610
# [1] "PP abf for shared variant: 0.061%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#  2.57e-58  6.23e-09  4.13e-50  1.00e+00  7.57e-11
# [1] "PP abf for shared variant: 7.57e-09%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#  4.59e-09  1.51e-09  7.36e-01  2.42e-01  2.18e-02
# [1] "PP abf for shared variant: 2.18%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#  1.67e-11  6.21e-09  2.68e-03  9.97e-01  5.91e-05
# [1] "PP abf for shared variant: 0.00591%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#  6.08e-66  6.23e-09  9.77e-58  1.00e+00  8.77e-11
# [1] "PP abf for shared variant: 8.77e-09%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#  2.77e-09  3.39e-09  4.45e-01  5.45e-01  1.00e-02
# [1] "PP abf for shared variant: 1%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#  8.57e-16  6.23e-09  1.38e-07  1.00e+00  5.07e-09
# [1] "PP abf for shared variant: 5.07e-07%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#  6.08e-10  5.54e-09  9.76e-02  8.90e-01  1.24e-02
# [1] "PP abf for shared variant: 1.24%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#  1.10e-09  5.10e-09  1.77e-01  8.18e-01  5.18e-03
# [1] "PP abf for shared variant: 0.518%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#  3.98e-09  1.88e-09  6.39e-01  3.02e-01  5.98e-02
# [1] "PP abf for shared variant: 5.98%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#  3.79e-09  2.30e-09  6.09e-01  3.70e-01  2.16e-02
# [1] "PP abf for shared variant: 2.16%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#  9.87e-01  8.43e-03  4.73e-03  4.02e-05  2.51e-04
# [1] "PP abf for shared variant: 0.0251%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#  4.59e-09  1.44e-09  7.37e-01  2.31e-01  3.24e-02
# [1] "PP abf for shared variant: 3.24%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#   0.92200   0.04750   0.02710   0.00139   0.00181
# [1] "PP abf for shared variant: 0.181%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#  0.944000  0.025600  0.027700  0.000749  0.001630
# [1] "PP abf for shared variant: 0.163%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#  9.90e-01  6.62e-03  3.48e-03  2.31e-05  2.20e-04
# [1] "PP abf for shared variant: 0.022%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#  1.00e+00  3.26e-05  1.84e-05  0.00e+00  6.02e-07
# [1] "PP abf for shared variant: 6.02e-05%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#  9.95e-01  3.28e-03  1.55e-03  4.98e-06  1.10e-04
# [1] "PP abf for shared variant: 0.011%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#  9.23e-22  6.78e-08  1.36e-14  1.00e+00  3.06e-08
# [1] "PP abf for shared variant: 3.06e-06%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#  6.78e-16  3.57e-10  1.09e-07  5.64e-02  9.44e-01
# [1] "PP abf for shared variant: 94.4%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#  3.25e-12  6.78e-08  4.80e-05  1.00e+00  2.82e-06
# [1] "PP abf for shared variant: 0.000282%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#  9.97e-01  1.53e-03  1.26e-03  1.87e-06  5.95e-05
# [1] "PP abf for shared variant: 0.00595%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#  9.24e-46  6.23e-09  1.48e-37  1.00e+00  6.35e-10
# [1] "PP abf for shared variant: 6.35e-08%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#  7.05e-12  1.02e-09  1.13e-03  1.64e-01  8.35e-01
# [1] "PP abf for shared variant: 83.5%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#   0.91700   0.05720   0.02230   0.00139   0.00196
# [1] "PP abf for shared variant: 0.196%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#  2.16e-65  6.23e-09  3.47e-57  1.00e+00  1.37e-10
# [1] "PP abf for shared variant: 1.37e-08%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#  3.10e-14  6.23e-09  4.98e-06  1.00e+00  8.13e-07
# [1] "PP abf for shared variant: 8.13e-05%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#  1.32e-09  4.76e-09  2.12e-01  7.65e-01  2.33e-02
# [1] "PP abf for shared variant: 2.33%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#  8.14e-29  1.08e-10  5.82e-19  7.70e-01  2.30e-01
# [1] "PP abf for shared variant: 23%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#  7.75e-15  1.40e-10  5.52e-05  1.00e+00  3.25e-06
# [1] "PP abf for shared variant: 0.000325%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#  1.19e-10  1.65e-11  8.49e-01  1.17e-01  3.35e-02
# [1] "PP abf for shared variant: 3.35%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#   0.92100   0.03820   0.03650   0.00151   0.00260
# [1] "PP abf for shared variant: 0.26%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#  0.941000  0.018900  0.037300  0.000746  0.001590
# [1] "PP abf for shared variant: 0.159%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#  5.78e-60  1.40e-10  4.13e-50  1.00e+00  2.72e-12
# [1] "PP abf for shared variant: 2.72e-10%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#  1.03e-10  3.38e-11  7.34e-01  2.41e-01  2.46e-02
# [1] "PP abf for shared variant: 2.46%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#  3.76e-13  1.40e-10  2.68e-03  9.97e-01  5.60e-05
# [1] "PP abf for shared variant: 0.0056%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#  1.37e-67  1.40e-10  9.77e-58  1.00e+00  3.00e-12
# [1] "PP abf for shared variant: 3e-10%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#  6.22e-11  7.61e-11  4.44e-01  5.44e-01  1.21e-02
# [1] "PP abf for shared variant: 1.21%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#  1.93e-17  1.40e-10  1.38e-07  1.00e+00  1.58e-08
# [1] "PP abf for shared variant: 1.58e-06%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#  1.36e-11  1.25e-10  9.75e-02  8.90e-01  1.27e-02
# [1] "PP abf for shared variant: 1.27%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#  2.47e-11  1.15e-10  1.77e-01  8.19e-01  3.93e-03
# [1] "PP abf for shared variant: 0.393%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#  9.00e-11  4.25e-11  6.43e-01  3.04e-01  5.35e-02
# [1] "PP abf for shared variant: 5.35%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#  8.53e-11  5.18e-11  6.09e-01  3.70e-01  2.05e-02
# [1] "PP abf for shared variant: 2.05%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#  0.974000  0.008330  0.016500  0.000140  0.000622
# [1] "PP abf for shared variant: 0.0622%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#  1.03e-10  3.23e-11  7.37e-01  2.31e-01  3.16e-02
# [1] "PP abf for shared variant: 3.16%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#   0.89200   0.04590   0.05590   0.00287   0.00359
# [1] "PP abf for shared variant: 0.359%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#   0.91400   0.02480   0.05730   0.00155   0.00195
# [1] "PP abf for shared variant: 0.195%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#  9.79e-01  6.55e-03  1.41e-02  9.39e-05  6.15e-04
# [1] "PP abf for shared variant: 0.0615%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#  1.00e+00  3.26e-05  2.78e-05  0.00e+00  9.09e-07
# [1] "PP abf for shared variant: 9.09e-05%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#  0.986000  0.003250  0.010100  0.000033  0.000306
# [1] "PP abf for shared variant: 0.0306%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#  1.12e-23  8.20e-10  1.27e-14  9.30e-01  6.97e-02
# [1] "PP abf for shared variant: 6.97%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#  1.63e-17  8.59e-12  1.12e-07  5.79e-02  9.42e-01
# [1] "PP abf for shared variant: 94.2%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#  5.72e-14  1.19e-09  4.80e-05  1.00e+00  2.21e-06
# [1] "PP abf for shared variant: 0.000221%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#  9.89e-01  1.52e-03  9.57e-03  1.44e-05  2.52e-04
# [1] "PP abf for shared variant: 0.0252%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#  2.08e-47  1.40e-10  1.48e-37  1.00e+00  6.08e-12
# [1] "PP abf for shared variant: 6.08e-10%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#  1.57e-13  2.28e-11  1.12e-03  1.62e-01  8.36e-01
# [1] "PP abf for shared variant: 83.6%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#   0.89200   0.05570   0.04530   0.00282   0.00394
# [1] "PP abf for shared variant: 0.394%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#  4.86e-67  1.40e-10  3.47e-57  1.00e+00  4.01e-10
# [1] "PP abf for shared variant: 4.01e-08%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#  6.96e-16  1.40e-10  4.98e-06  1.00e+00  7.66e-07
# [1] "PP abf for shared variant: 7.66e-05%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#  2.97e-11  1.07e-10  2.13e-01  7.66e-01  2.16e-02
# [1] "PP abf for shared variant: 2.16%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#  2.36e-10  2.19e-04  1.08e-06  1.00e+00  7.75e-06
# [1] "PP abf for shared variant: 0.000775%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#   0.92300   0.03460   0.03890   0.00146   0.00241
# [1] "PP abf for shared variant: 0.241%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#   0.92300   0.03390   0.03900   0.00143   0.00233
# [1] "PP abf for shared variant: 0.233%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#   0.92300   0.03470   0.03890   0.00146   0.00234
# [1] "PP abf for shared variant: 0.234%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#  3.92e-07  2.18e-04  1.79e-03  9.98e-01  4.42e-04
# [1] "PP abf for shared variant: 0.0442%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#   0.94400   0.03270   0.02080   0.00072   0.00177
# [1] "PP abf for shared variant: 0.177%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#   0.76000   0.16300   0.05670   0.01220   0.00746
# [1] "PP abf for shared variant: 0.746%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#    0.5930    0.3230    0.0442    0.0241    0.0162
# [1] "PP abf for shared variant: 1.62%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#  2.23e-08  2.19e-04  1.02e-04  1.00e+00  8.64e-06
# [1] "PP abf for shared variant: 0.000864%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#  6.92e-05  1.49e-04  3.16e-01  6.79e-01  3.95e-03
# [1] "PP abf for shared variant: 0.395%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
# 4.00e-206  2.19e-04 1.83e-202  1.00e+00  7.67e-06
# [1] "PP abf for shared variant: 0.000767%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#  8.41e-10  2.19e-04  3.85e-06  1.00e+00  6.20e-06
# [1] "PP abf for shared variant: 0.00062%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#  1.31e-12  2.19e-04  6.00e-09  1.00e+00  6.52e-06
# [1] "PP abf for shared variant: 0.000652%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#   0.92300   0.05470   0.01910   0.00113   0.00258
# [1] "PP abf for shared variant: 0.258%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#  0.981000  0.004540  0.014300  0.000066  0.000350
# [1] "PP abf for shared variant: 0.035%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#  9.79e-01  6.16e-03  1.43e-02  8.96e-05  4.10e-04
# [1] "PP abf for shared variant: 0.041%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#  9.79e-01  6.04e-03  1.43e-02  8.79e-05  4.45e-04
# [1] "PP abf for shared variant: 0.0445%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#  0.959000  0.027000  0.012200  0.000343  0.001520
# [1] "PP abf for shared variant: 0.152%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#  9.79e-01  7.56e-03  1.25e-02  9.56e-05  6.09e-04
# [1] "PP abf for shared variant: 0.0609%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#  6.66e-17  1.94e-04  3.05e-13  8.88e-01  1.11e-01
# [1] "PP abf for shared variant: 11.1%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#  7.66e-07  2.13e-04  3.50e-03  9.76e-01  2.05e-02
# [1] "PP abf for shared variant: 2.05%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#  1.77e-06  2.02e-04  8.08e-03  9.25e-01  6.70e-02
# [1] "PP abf for shared variant: 6.7%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#  9.39e-05  1.18e-04  4.29e-01  5.42e-01  2.90e-02
# [1] "PP abf for shared variant: 2.9%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#  0.000173  0.000035  0.793000  0.160000  0.047100
# [1] "PP abf for shared variant: 4.71%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#  9.27e-06  2.55e-02  3.54e-04  9.73e-01  1.26e-03
# [1] "PP abf for shared variant: 0.126%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#  1.61e-04  3.39e-05  7.34e-01  1.55e-01  1.10e-01
# [1] "PP abf for shared variant: 11%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#  1.11e-04  9.04e-05  5.10e-01  4.13e-01  7.64e-02
# [1] "PP abf for shared variant: 7.64%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#  1.69e-04  3.73e-05  7.74e-01  1.70e-01  5.59e-02
# [1] "PP abf for shared variant: 5.59%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#  3.27e-44  3.65e-04  8.94e-41  9.98e-01  1.47e-03
# [1] "PP abf for shared variant: 0.147%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#  5.65e-07  5.60e-07  2.58e-03  1.57e-03  9.96e-01
# [1] "PP abf for shared variant: 99.6%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#   0.91000   0.04110   0.04350   0.00196   0.00302
# [1] "PP abf for shared variant: 0.302%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#   0.90800   0.04360   0.04340   0.00208   0.00321
# [1] "PP abf for shared variant: 0.321%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#  1.65e-22  2.19e-04  7.56e-19  1.00e+00  8.79e-06
# [1] "PP abf for shared variant: 0.000879%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#  8.75e-12  2.19e-04  4.00e-08  1.00e+00  8.33e-06
# [1] "PP abf for shared variant: 0.000833%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#   0.90700   0.04820   0.03960   0.00210   0.00349
# [1] "PP abf for shared variant: 0.349%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#   0.93200   0.02520   0.04060   0.00110   0.00156
# [1] "PP abf for shared variant: 0.156%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#  4.02e-07  2.18e-04  1.84e-03  9.98e-01  1.03e-04
# [1] "PP abf for shared variant: 0.0103%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#   0.02130   0.00351   0.81400   0.13400   0.02730
# [1] "PP abf for shared variant: 2.73%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#   0.55400   0.41400   0.00977   0.00729   0.01580
# [1] "PP abf for shared variant: 1.58%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#  5.52e-12  2.19e-04  2.53e-08  1.00e+00  9.41e-06
# [1] "PP abf for shared variant: 0.000941%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#   0.89500   0.05860   0.03910   0.00255   0.00429
# [1] "PP abf for shared variant: 0.429%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#   0.92400   0.03200   0.04030   0.00139   0.00188
# [1] "PP abf for shared variant: 0.188%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#  7.19e-08  2.60e-02  2.69e-06  9.73e-01  1.27e-03
# [1] "PP abf for shared variant: 0.127%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#  9.30e-07  2.18e-04  4.26e-03  9.95e-01  1.38e-04
# [1] "PP abf for shared variant: 0.0138%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#  2.84e-05  1.89e-04  1.30e-01  8.64e-01  5.50e-03
# [1] "PP abf for shared variant: 0.55%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#   0.91800   0.03900   0.03870   0.00164   0.00255
# [1] "PP abf for shared variant: 0.255%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#  1.30e-07  2.18e-04  5.97e-04  9.99e-01  3.47e-05
# [1] "PP abf for shared variant: 0.00347%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#  1.31e-13  2.19e-04  6.01e-10  1.00e+00  2.02e-04
# [1] "PP abf for shared variant: 0.0202%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#  3.03e-24  2.19e-04  1.39e-20  9.99e-01  6.63e-04
# [1] "PP abf for shared variant: 0.0663%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#  6.29e-11  1.96e-04  2.88e-07  8.97e-01  1.03e-01
# [1] "PP abf for shared variant: 10.3%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#  1.81e-04  2.59e-05  8.29e-01  1.18e-01  5.20e-02
# [1] "PP abf for shared variant: 5.2%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#  1.74e-04  3.52e-05  7.97e-01  1.61e-01  4.24e-02
# [1] "PP abf for shared variant: 4.24%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#  1.80e-04  3.12e-05  8.22e-01  1.42e-01  3.51e-02
# [1] "PP abf for shared variant: 3.51%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#  1.84e-04  2.68e-05  8.42e-01  1.22e-01  3.55e-02
# [1] "PP abf for shared variant: 3.55%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#  1.37e-07  2.20e-04  6.23e-04  9.99e-01  1.71e-05
# [1] "PP abf for shared variant: 0.00171%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#  2.54e-05  1.94e-04  1.15e-01  8.79e-01  5.22e-03
# [1] "PP abf for shared variant: 0.522%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#  3.29e-16  2.19e-04  1.50e-12  1.00e+00  8.67e-06
# [1] "PP abf for shared variant: 0.000867%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#  3.38e-13  2.19e-04  1.55e-09  1.00e+00  7.67e-06
# [1] "PP abf for shared variant: 0.000767%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#  1.69e-07  2.18e-04  7.75e-04  9.99e-01  6.15e-05
# [1] "PP abf for shared variant: 0.00615%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#  3.95e-12  2.18e-04  1.81e-08  9.99e-01  3.41e-04
# [1] "PP abf for shared variant: 0.0341%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#  1.55e-04  6.01e-05  7.09e-01  2.75e-01  1.59e-02
# [1] "PP abf for shared variant: 1.59%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#  9.23e-05  1.22e-04  4.22e-01  5.60e-01  1.80e-02
# [1] "PP abf for shared variant: 1.8%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#  7.69e-11  1.89e-04  3.52e-07  8.66e-01  1.34e-01
# [1] "PP abf for shared variant: 13.4%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#  6.80e-06  2.06e-04  3.11e-02  9.40e-01  2.87e-02
# [1] "PP abf for shared variant: 2.87%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#  1.85e-07  1.85e-04  8.44e-04  8.44e-01  1.54e-01
# [1] "PP abf for shared variant: 15.4%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#  0.000166  0.000042  0.758000  0.192000  0.050100
# [1] "PP abf for shared variant: 5.01%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#  3.13e-13  2.19e-04  1.43e-09  1.00e+00  1.48e-05
# [1] "PP abf for shared variant: 0.00148%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#  3.94e-11  2.19e-04  1.80e-07  1.00e+00  8.33e-06
# [1] "PP abf for shared variant: 0.000833%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#    0.6330    0.2800    0.0419    0.0185    0.0261
# [1] "PP abf for shared variant: 2.61%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#   0.09580   0.82000   0.00635   0.05430   0.02400
# [1] "PP abf for shared variant: 2.4%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#    0.2400    0.6770    0.0159    0.0448    0.0221
# [1] "PP abf for shared variant: 2.21%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#   0.85400   0.09180   0.04060   0.00435   0.00916
# [1] "PP abf for shared variant: 0.916%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#   0.91400   0.03810   0.04340   0.00181   0.00300
# [1] "PP abf for shared variant: 0.3%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#   0.90900   0.04250   0.04310   0.00201   0.00379
# [1] "PP abf for shared variant: 0.379%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#  9.83e-01  6.11e-03  1.07e-02  6.61e-05  5.62e-04
# [1] "PP abf for shared variant: 0.0562%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#    0.6690    0.2480    0.0335    0.0124    0.0368
# [1] "PP abf for shared variant: 3.68%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#  3.15e-11  2.19e-04  1.44e-07  1.00e+00  2.47e-05
# [1] "PP abf for shared variant: 0.00247%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#  1.89e-04  2.47e-05  8.63e-01  1.13e-01  2.33e-02
# [1] "PP abf for shared variant: 2.33%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#  1.99e-05  2.00e-04  9.04e-02  9.07e-01  2.81e-03
# [1] "PP abf for shared variant: 0.281%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#   0.87200   0.05490   0.06500   0.00409   0.00391
# [1] "PP abf for shared variant: 0.391%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#   0.87300   0.10100   0.01900   0.00219   0.00509
# [1] "PP abf for shared variant: 0.509%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#  1.52e-04  6.05e-05  6.97e-01  2.77e-01  2.66e-02
# [1] "PP abf for shared variant: 2.66%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#   0.93400   0.02390   0.03940   0.00101   0.00183
# [1] "PP abf for shared variant: 0.183%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#  1.77e-10  2.19e-04  8.11e-07  1.00e+00  8.45e-06
# [1] "PP abf for shared variant: 0.000845%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#  5.71e-05  1.59e-04  2.61e-01  7.26e-01  1.19e-02
# [1] "PP abf for shared variant: 1.19%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#  0.970000  0.013400  0.015800  0.000217  0.000982
# [1] "PP abf for shared variant: 0.0982%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#  2.12e-20  1.97e-14  1.08e-06  1.00e+00  5.44e-08
# [1] "PP abf for shared variant: 5.44e-06%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#   0.91300   0.03430   0.04840   0.00181   0.00248
# [1] "PP abf for shared variant: 0.248%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#   0.91400   0.03350   0.04840   0.00177   0.00244
# [1] "PP abf for shared variant: 0.244%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#   0.91300   0.03440   0.04840   0.00182   0.00257
# [1] "PP abf for shared variant: 0.257%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#  3.53e-17  1.97e-14  1.79e-03  9.98e-01  1.92e-05
# [1] "PP abf for shared variant: 0.00192%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#  0.939000  0.032600  0.025800  0.000893  0.001670
# [1] "PP abf for shared variant: 0.167%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#    0.7290    0.1560    0.0853    0.0183    0.0111
# [1] "PP abf for shared variant: 1.11%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#    0.5680    0.3100    0.0665    0.0362    0.0196
# [1] "PP abf for shared variant: 1.96%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#  2.01e-18  1.97e-14  1.02e-04  1.00e+00  1.63e-06
# [1] "PP abf for shared variant: 0.000163%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#  6.23e-15  1.34e-14  3.16e-01  6.80e-01  4.08e-03
# [1] "PP abf for shared variant: 0.408%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
# 3.60e-216  1.97e-14 1.83e-202  1.00e+00  8.83e-16
# [1] "PP abf for shared variant: 8.83e-14%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#  7.58e-20  1.97e-14  3.85e-06  1.00e+00  1.17e-07
# [1] "PP abf for shared variant: 1.17e-05%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#  1.18e-22  1.97e-14  6.00e-09  1.00e+00  1.69e-10
# [1] "PP abf for shared variant: 1.69e-08%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#   0.92100   0.05450   0.02080   0.00123   0.00276
# [1] "PP abf for shared variant: 0.276%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#  9.81e-01  4.54e-03  1.39e-02  6.42e-05  3.12e-04
# [1] "PP abf for shared variant: 0.0312%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#  0.979000  0.006160  0.013900  0.000087  0.000391
# [1] "PP abf for shared variant: 0.0391%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#  9.80e-01  6.04e-03  1.39e-02  8.54e-05  3.97e-04
# [1] "PP abf for shared variant: 0.0397%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#  0.962000  0.027100  0.009190  0.000258  0.001370
# [1] "PP abf for shared variant: 0.137%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#  0.983000  0.007580  0.009390  0.000072  0.000424
# [1] "PP abf for shared variant: 0.0424%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#  6.43e-27  1.88e-14  3.27e-13  9.52e-01  4.76e-02
# [1] "PP abf for shared variant: 4.76%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#  6.99e-17  1.95e-14  3.55e-03  9.89e-01  7.49e-03
# [1] "PP abf for shared variant: 0.749%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#  1.70e-16  1.95e-14  8.65e-03  9.90e-01  1.11e-03
# [1] "PP abf for shared variant: 0.111%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#  8.28e-15  1.04e-14  4.20e-01  5.30e-01  4.97e-02
# [1] "PP abf for shared variant: 4.97%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#  1.55e-14  3.12e-15  7.86e-01  1.58e-01  5.61e-02
# [1] "PP abf for shared variant: 5.61%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#  1.28e-14  3.53e-11  3.63e-04  1.00e+00  1.05e-05
# [1] "PP abf for shared variant: 0.00105%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#  1.45e-14  3.05e-15  7.34e-01  1.55e-01  1.11e-01
# [1] "PP abf for shared variant: 11.1%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#  1.00e-14  8.14e-15  5.10e-01  4.13e-01  7.64e-02
# [1] "PP abf for shared variant: 7.64%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#  1.51e-14  3.32e-15  7.66e-01  1.69e-01  6.55e-02
# [1] "PP abf for shared variant: 6.55%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#  1.65e-53  1.84e-13  8.96e-41  1.00e+00  8.45e-13
# [1] "PP abf for shared variant: 8.45e-11%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#  4.98e-17  4.94e-17  2.53e-03  1.51e-03  9.96e-01
# [1] "PP abf for shared variant: 99.6%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#   0.87100   0.03930   0.08180   0.00369   0.00428
# [1] "PP abf for shared variant: 0.428%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#   0.86800   0.04170   0.08160   0.00392   0.00448
# [1] "PP abf for shared variant: 0.448%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#  1.49e-32  1.97e-14  7.56e-19  1.00e+00  1.31e-15
# [1] "PP abf for shared variant: 1.31e-13%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#  7.88e-22  1.97e-14  4.00e-08  1.00e+00  4.51e-10
# [1] "PP abf for shared variant: 4.51e-08%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#   0.89600   0.04770   0.04900   0.00260   0.00446
# [1] "PP abf for shared variant: 0.446%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#   0.92200   0.02490   0.05030   0.00136   0.00182
# [1] "PP abf for shared variant: 0.182%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#  3.62e-17  1.97e-14  1.84e-03  9.98e-01  9.77e-05
# [1] "PP abf for shared variant: 0.00977%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#  2.97e-11  4.89e-12  8.42e-01  1.38e-01  1.99e-02
# [1] "PP abf for shared variant: 1.99%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#   0.51800   0.38700   0.01020   0.00756   0.07800
# [1] "PP abf for shared variant: 7.8%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#  4.98e-22  1.97e-14  2.53e-08  1.00e+00  3.44e-09
# [1] "PP abf for shared variant: 3.44e-07%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#   0.88600   0.05800   0.04840   0.00317   0.00398
# [1] "PP abf for shared variant: 0.398%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#   0.91400   0.03170   0.05000   0.00173   0.00224
# [1] "PP abf for shared variant: 0.224%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#  2.73e-08  9.87e-03  2.74e-06  9.90e-01  6.05e-04
# [1] "PP abf for shared variant: 0.0605%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#  8.38e-17  1.96e-14  4.26e-03  9.96e-01  1.13e-04
# [1] "PP abf for shared variant: 0.0113%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#  2.56e-15  1.70e-14  1.30e-01  8.65e-01  5.32e-03
# [1] "PP abf for shared variant: 0.532%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#   0.90800   0.03860   0.04810   0.00204   0.00312
# [1] "PP abf for shared variant: 0.312%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#  1.18e-17  1.97e-14  5.97e-04  9.99e-01  1.75e-05
# [1] "PP abf for shared variant: 0.00175%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#  1.19e-23  1.97e-14  6.01e-10  1.00e+00  1.42e-10
# [1] "PP abf for shared variant: 1.42e-08%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#  2.74e-34  1.97e-14  1.39e-20  1.00e+00  2.78e-15
# [1] "PP abf for shared variant: 2.78e-13%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#  6.03e-21  1.88e-14  3.06e-07  9.54e-01  4.56e-02
# [1] "PP abf for shared variant: 4.56%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#  1.63e-14  2.33e-15  8.27e-01  1.18e-01  5.55e-02
# [1] "PP abf for shared variant: 5.55%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#  1.54e-14  3.11e-15  7.81e-01  1.58e-01  6.11e-02
# [1] "PP abf for shared variant: 6.11%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#  1.62e-14  2.81e-15  8.22e-01  1.42e-01  3.58e-02
# [1] "PP abf for shared variant: 3.58%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#  1.66e-14  2.41e-15  8.41e-01  1.22e-01  3.66e-02
# [1] "PP abf for shared variant: 3.66%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#  1.23e-17  1.97e-14  6.23e-04  9.99e-01  1.02e-05
# [1] "PP abf for shared variant: 0.00102%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#  2.27e-15  1.73e-14  1.15e-01  8.80e-01  5.13e-03
# [1] "PP abf for shared variant: 0.513%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#  2.96e-26  1.97e-14  1.50e-12  1.00e+00  3.13e-13
# [1] "PP abf for shared variant: 3.13e-11%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#  3.05e-23  1.97e-14  1.55e-09  1.00e+00  3.95e-10
# [1] "PP abf for shared variant: 3.95e-08%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#  1.53e-17  1.97e-14  7.75e-04  9.99e-01  5.02e-05
# [1] "PP abf for shared variant: 0.00502%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#  3.56e-22  1.97e-14  1.81e-08  1.00e+00  3.15e-10
# [1] "PP abf for shared variant: 3.15e-08%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#  1.40e-14  5.42e-15  7.09e-01  2.75e-01  1.54e-02
# [1] "PP abf for shared variant: 1.54%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#  8.34e-15  1.11e-14  4.24e-01  5.61e-01  1.49e-02
# [1] "PP abf for shared variant: 1.49%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#  5.14e-21  1.27e-14  2.61e-07  6.42e-01  3.58e-01
# [1] "PP abf for shared variant: 35.8%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#  6.17e-16  1.87e-14  3.13e-02  9.47e-01  2.17e-02
# [1] "PP abf for shared variant: 2.17%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#  1.69e-17  1.69e-14  8.59e-04  8.59e-01  1.40e-01
# [1] "PP abf for shared variant: 14%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#  1.49e-14  3.77e-15  7.54e-01  1.91e-01  5.51e-02
# [1] "PP abf for shared variant: 5.51%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#  2.82e-23  1.97e-14  1.43e-09  1.00e+00  2.22e-11
# [1] "PP abf for shared variant: 2.22e-09%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#  3.55e-21  1.97e-14  1.80e-07  1.00e+00  4.06e-09
# [1] "PP abf for shared variant: 4.06e-07%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#    0.6160    0.2730    0.0630    0.0279    0.0204
# [1] "PP abf for shared variant: 2.04%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#   0.09270   0.79300   0.00948   0.08110   0.02380
# [1] "PP abf for shared variant: 2.38%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#    0.2320    0.6550    0.0238    0.0670    0.0216
# [1] "PP abf for shared variant: 2.16%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#   0.81700   0.08780   0.07660   0.00823   0.01080
# [1] "PP abf for shared variant: 1.08%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#   0.87300   0.03640   0.08190   0.00341   0.00554
# [1] "PP abf for shared variant: 0.554%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#   0.86800   0.04060   0.08150   0.00380   0.00622
# [1] "PP abf for shared variant: 0.622%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#  9.85e-01  6.13e-03  8.00e-03  4.94e-05  3.63e-04
# [1] "PP abf for shared variant: 0.0363%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#    0.6800    0.2520    0.0401    0.0148    0.0139
# [1] "PP abf for shared variant: 1.39%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#  2.84e-21  1.97e-14  1.44e-07  1.00e+00  4.24e-09
# [1] "PP abf for shared variant: 4.24e-07%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#  1.70e-14  2.23e-15  8.63e-01  1.13e-01  2.37e-02
# [1] "PP abf for shared variant: 2.37%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#  1.78e-15  1.79e-14  9.04e-02  9.07e-01  2.78e-03
# [1] "PP abf for shared variant: 0.278%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#   0.83700   0.05270   0.09800   0.00616   0.00618
# [1] "PP abf for shared variant: 0.618%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#   0.87000   0.10100   0.02300   0.00266   0.00406
# [1] "PP abf for shared variant: 0.406%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#  1.37e-14  5.45e-15  6.97e-01  2.77e-01  2.59e-02
# [1] "PP abf for shared variant: 2.59%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#   0.92400   0.02370   0.04900   0.00125   0.00168
# [1] "PP abf for shared variant: 0.168%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#  1.60e-20  1.97e-14  8.11e-07  1.00e+00  2.64e-08
# [1] "PP abf for shared variant: 2.64e-06%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#  5.15e-15  1.43e-14  2.62e-01  7.27e-01  1.13e-02
# [1] "PP abf for shared variant: 1.13%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#  0.968000  0.013300  0.017800  0.000244  0.000926
# [1] "PP abf for shared variant: 0.0926%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#  6.54e-86  2.22e-41  2.96e-48  2.47e-06  1.00e+00
# [1] "PP abf for shared variant: 100%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#  2.26e-46  2.29e-41  1.02e-08  3.59e-05  1.00e+00
# [1] "PP abf for shared variant: 100%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#  8.46e-41  3.11e-41  3.83e-03  4.11e-04  9.96e-01
# [1] "PP abf for shared variant: 99.6%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#  8.90e-39  2.75e-41  4.02e-01  6.49e-04  5.97e-01
# [1] "PP abf for shared variant: 59.7%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#  5.04e-60  5.33e-40  2.28e-22  2.31e-02  9.77e-01
# [1] "PP abf for shared variant: 97.7%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#  5.04e-40  6.64e-41  2.28e-02  2.03e-03  9.75e-01
# [1] "PP abf for shared variant: 97.5%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#  2.14e-38  3.30e-42  9.67e-01  1.16e-04  3.27e-02
# [1] "PP abf for shared variant: 3.27%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#  1.73e-40  2.43e-41  7.81e-03  1.08e-04  9.92e-01
# [1] "PP abf for shared variant: 99.2%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#  2.50e-33  2.65e-35  6.29e-01  6.29e-03  3.65e-01
# [1] "PP abf for shared variant: 36.5%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#  4.07e-33  1.32e-36  9.69e-01  2.84e-04  3.10e-02
# [1] "PP abf for shared variant: 3.1%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#  4.07e-33  2.45e-37  9.71e-01  2.92e-05  2.91e-02
# [1] "PP abf for shared variant: 2.91%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#  1.28e-39  3.79e-40  5.78e-02  1.62e-02  9.26e-01
# [1] "PP abf for shared variant: 92.6%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#  3.74e-56  1.27e-11  1.29e-46  4.29e-02  9.57e-01
# [1] "PP abf for shared variant: 95.7%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#  7.41e-17  7.49e-12  2.57e-07  2.50e-02  9.75e-01
# [1] "PP abf for shared variant: 97.5%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#  5.73e-12  2.11e-12  1.98e-02  6.32e-03  9.74e-01
# [1] "PP abf for shared variant: 97.4%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#  1.79e-10  5.53e-13  6.19e-01  1.54e-03  3.79e-01
# [1] "PP abf for shared variant: 37.9%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#  5.69e-33  6.02e-13  1.97e-23  1.09e-03  9.99e-01
# [1] "PP abf for shared variant: 99.9%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#  6.77e-12  8.92e-13  2.34e-02  2.11e-03  9.74e-01
# [1] "PP abf for shared variant: 97.4%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#  7.18e-10  1.11e-13  9.68e-01  1.18e-04  3.14e-02
# [1] "PP abf for shared variant: 3.14%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#  2.61e-11  3.68e-12  9.04e-02  1.18e-02  8.98e-01
# [1] "PP abf for shared variant: 89.8%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#  2.83e-10  3.00e-12  9.61e-01  1.02e-02  2.85e-02
# [1] "PP abf for shared variant: 2.85%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#  2.86e-10  9.29e-14  9.69e-01  2.84e-04  3.09e-02
# [1] "PP abf for shared variant: 3.09%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#  2.86e-10  1.72e-14  9.71e-01  2.92e-05  2.91e-02
# [1] "PP abf for shared variant: 2.91%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#  2.16e-12  6.40e-13  7.48e-03  1.22e-03  9.91e-01
# [1] "PP abf for shared variant: 99.1%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#  1.33e-71  4.51e-27  2.97e-48  6.83e-06  1.00e+00
# [1] "PP abf for shared variant: 100%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#  4.61e-32  4.66e-27  1.03e-08  4.03e-05  1.00e+00
# [1] "PP abf for shared variant: 100%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#  1.72e-26  6.33e-27  3.84e-03  4.16e-04  9.96e-01
# [1] "PP abf for shared variant: 99.6%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#  1.81e-24  5.59e-27  4.03e-01  6.51e-04  5.96e-01
# [1] "PP abf for shared variant: 59.6%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#  9.74e-46  1.03e-25  2.17e-22  2.20e-02  9.78e-01
# [1] "PP abf for shared variant: 97.8%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#  1.02e-25  1.35e-26  2.28e-02  2.03e-03  9.75e-01
# [1] "PP abf for shared variant: 97.5%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#  4.35e-24  6.71e-28  9.67e-01  1.16e-04  3.27e-02
# [1] "PP abf for shared variant: 3.27%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#  3.51e-26  4.95e-27  7.84e-03  1.12e-04  9.92e-01
# [1] "PP abf for shared variant: 99.2%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#  9.93e-22  1.05e-23  9.61e-01  1.02e-02  2.84e-02
# [1] "PP abf for shared variant: 2.84%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#  1.00e-21  3.26e-25  9.69e-01  2.85e-04  3.05e-02
# [1] "PP abf for shared variant: 3.05%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#  1.00e-21  6.02e-26  9.71e-01  2.94e-05  2.89e-02
# [1] "PP abf for shared variant: 2.89%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#  2.51e-25  7.46e-26  5.61e-02  1.57e-02  9.28e-01
# [1] "PP abf for shared variant: 92.8%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#  3.06e-33  2.76e-34  8.55e-01  7.69e-02  6.86e-02
# [1] "PP abf for shared variant: 6.86%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#  3.05e-33  2.94e-34  8.52e-01  8.20e-02  6.56e-02
# [1] "PP abf for shared variant: 6.56%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#  1.29e-37  3.58e-33  3.59e-05  1.00e+00  6.39e-07
# [1] "PP abf for shared variant: 6.39e-05%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#  0.960000  0.017000  0.021300  0.000376  0.000948
# [1] "PP abf for shared variant: 0.0948%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#   0.92300   0.02780   0.04590   0.00138   0.00200
# [1] "PP abf for shared variant: 0.2%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#  0.931000  0.019300  0.046800  0.000967  0.001560
# [1] "PP abf for shared variant: 0.156%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#  1.88e-33  1.64e-33  5.29e-01  4.62e-01  8.43e-03
# [1] "PP abf for shared variant: 0.843%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#  2.46e-33  1.05e-33  6.92e-01  2.97e-01  1.16e-02
# [1] "PP abf for shared variant: 1.16%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#   0.83600   0.07680   0.07480   0.00686   0.00521
# [1] "PP abf for shared variant: 0.521%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#   0.89100   0.02750   0.07710   0.00238   0.00214
# [1] "PP abf for shared variant: 0.214%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#   0.90300   0.04640   0.04580   0.00235   0.00275
# [1] "PP abf for shared variant: 0.275%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#   0.87700   0.07040   0.04420   0.00354   0.00501
# [1] "PP abf for shared variant: 0.501%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#  2.16e-32  1.58e-29  1.36e-03  9.99e-01  3.03e-05
# [1] "PP abf for shared variant: 0.00303%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#  1.36e-29  1.95e-30  8.58e-01  1.23e-01  1.91e-02
# [1] "PP abf for shared variant: 1.91%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#  9.92e-01  1.44e-03  6.24e-03  8.93e-06  1.11e-04
# [1] "PP abf for shared variant: 0.0111%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#  9.90e-01  1.88e-03  7.51e-03  1.41e-05  1.48e-04
# [1] "PP abf for shared variant: 0.0148%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#  2.01e-39  3.55e-33  5.65e-07  1.00e+00  9.34e-09
# [1] "PP abf for shared variant: 9.34e-07%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#  1.10e-35  3.54e-33  3.09e-03  9.97e-01  3.63e-05
# [1] "PP abf for shared variant: 0.00363%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#  2.24e-33  1.28e-33  6.31e-01  3.59e-01  1.00e-02
# [1] "PP abf for shared variant: 1%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#  0.944000  0.009340  0.045300  0.000447  0.000936
# [1] "PP abf for shared variant: 0.0936%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#  1.33e-54  3.55e-33  3.75e-22  1.00e+00  1.11e-23
# [1] "PP abf for shared variant: 1.11e-21%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#  1.46e-38  3.55e-33  4.11e-06  1.00e+00  7.88e-08
# [1] "PP abf for shared variant: 7.88e-06%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#  9.80e-01  1.15e-02  7.58e-03  8.85e-05  6.01e-04
# [1] "PP abf for shared variant: 0.0601%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#  0.983000  0.008480  0.007600  0.000065  0.000527
# [1] "PP abf for shared variant: 0.0527%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#  0.960000  0.030700  0.007420  0.000236  0.001500
# [1] "PP abf for shared variant: 0.15%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#   0.86400   0.05270   0.07490   0.00457   0.00393
# [1] "PP abf for shared variant: 0.393%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#   0.84100   0.13100   0.01760   0.00273   0.00804
# [1] "PP abf for shared variant: 0.804%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#  5.34e-49  3.55e-33  1.50e-16  1.00e+00  1.82e-18
# [1] "PP abf for shared variant: 1.82e-16%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#  3.32e-10  1.92e-10  6.20e-01  3.60e-01  2.00e-02
# [1] "PP abf for shared variant: 2%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#  5.73e-41  3.55e-33  1.61e-08  1.00e+00  2.96e-10
# [1] "PP abf for shared variant: 2.96e-08%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#  5.21e-48  3.55e-33  1.47e-15  1.00e+00  2.36e-17
# [1] "PP abf for shared variant: 2.36e-15%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#  1.04e-65  3.55e-33  2.92e-33  1.00e+00  2.41e-34
# [1] "PP abf for shared variant: 2.41e-32%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#  3.03e-40  3.55e-33  8.52e-08  1.00e+00  3.24e-09
# [1] "PP abf for shared variant: 3.24e-07%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#  6.41e-46  3.55e-33  1.80e-13  1.00e+00  4.16e-14
# [1] "PP abf for shared variant: 4.16e-12%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#  0.883000  0.107000  0.005230  0.000628  0.004760
# [1] "PP abf for shared variant: 0.476%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#  6.26e-35  4.82e-33  1.27e-02  9.81e-01  5.81e-03
# [1] "PP abf for shared variant: 0.581%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#  1.58e-36  4.31e-33  3.66e-04  1.00e+00  1.39e-05
# [1] "PP abf for shared variant: 0.00139%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#  1.84e-45  4.32e-33  4.26e-13  1.00e+00  2.21e-14
# [1] "PP abf for shared variant: 2.21e-12%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#   0.90600   0.04030   0.04810   0.00214   0.00353
# [1] "PP abf for shared variant: 0.353%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#   0.91700   0.02980   0.04870   0.00158   0.00264
# [1] "PP abf for shared variant: 0.264%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#  7.20e-34  2.82e-33  2.03e-01  7.93e-01  4.72e-03
# [1] "PP abf for shared variant: 0.472%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#  3.43e-58  3.85e-33  8.91e-26  1.00e+00  7.76e-27
# [1] "PP abf for shared variant: 7.76e-25%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#  3.37e-33  4.29e-34  8.73e-01  1.11e-01  1.54e-02
# [1] "PP abf for shared variant: 1.54%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#  4.38e-64  1.06e-34  1.23e-31  2.90e-02  9.71e-01
# [1] "PP abf for shared variant: 97.1%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#    0.6330    0.0373    0.3000    0.0177    0.0123
# [1] "PP abf for shared variant: 1.23%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#  9.81e-01  5.89e-03  1.26e-02  7.52e-05  3.38e-04
# [1] "PP abf for shared variant: 0.0338%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#  5.17e-64  7.77e-33  6.66e-32  1.00e+00  1.09e-26
# [1] "PP abf for shared variant: 1.09e-24%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#  4.59e-89  9.58e-35  1.29e-56  2.60e-02  9.74e-01
# [1] "PP abf for shared variant: 97.4%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#   0.90400   0.03190   0.05880   0.00207   0.00287
# [1] "PP abf for shared variant: 0.287%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#   0.90600   0.03510   0.05430   0.00210   0.00281
# [1] "PP abf for shared variant: 0.281%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#   0.87200   0.04340   0.07740   0.00385   0.00298
# [1] "PP abf for shared variant: 0.298%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#    0.6050    0.2850    0.0674    0.0318    0.0107
# [1] "PP abf for shared variant: 1.07%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#  2.97e-63  7.77e-33  3.82e-31  1.00e+00  1.20e-26
# [1] "PP abf for shared variant: 1.2e-24%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#  2.57e-96  1.19e-34  7.23e-64  3.25e-02  9.68e-01
# [1] "PP abf for shared variant: 96.8%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#  5.63e-31  5.02e-29  1.11e-02  9.88e-01  4.85e-04
# [1] "PP abf for shared variant: 0.0485%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#  3.62e-29  1.34e-29  7.13e-01  2.63e-01  2.39e-02
# [1] "PP abf for shared variant: 2.39%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#   0.90700   0.04080   0.04550   0.00204   0.00441
# [1] "PP abf for shared variant: 0.441%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#  0.988000  0.004020  0.007450  0.000030  0.000316
# [1] "PP abf for shared variant: 0.0316%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#  5.43e-35  2.77e-34  1.53e-02  7.69e-02  9.08e-01
# [1] "PP abf for shared variant: 90.8%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#  3.35e-65  5.62e-33  5.95e-33  1.00e+00  8.57e-27
# [1] "PP abf for shared variant: 8.57e-25%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#  3.70e-90  9.91e-35  1.04e-57  2.69e-02  9.73e-01
# [1] "PP abf for shared variant: 97.3%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#  6.81e-37  3.55e-33  1.92e-04  1.00e+00  3.62e-05
# [1] "PP abf for shared variant: 0.00362%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#  9.46e-47  8.52e-48  8.29e-01  7.46e-02  9.61e-02
# [1] "PP abf for shared variant: 9.61%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#  9.46e-47  9.10e-48  8.29e-01  7.97e-02  9.09e-02
# [1] "PP abf for shared variant: 9.09%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#  4.09e-51  1.14e-46  3.59e-05  1.00e+00  5.65e-07
# [1] "PP abf for shared variant: 5.65e-05%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
# ...
#   0.70000   0.09020   0.17700   0.02280   0.00977
# [1] "PP abf for shared variant: 0.977%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#  1.42e-05  3.62e-06  7.67e-01  1.96e-01  3.72e-02
# [1] "PP abf for shared variant: 3.72%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#  1.34e-05  4.80e-06  7.22e-01  2.59e-01  1.98e-02
# [1] "PP abf for shared variant: 1.98%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#  1.44e-05  3.69e-06  7.79e-01  2.00e-01  2.07e-02
# [1] "PP abf for shared variant: 2.07%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#   0.78300   0.05980   0.13900   0.01060   0.00753
# [1] "PP abf for shared variant: 0.753%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#  6.46e-14  1.84e-05  3.52e-09  1.00e+00  5.90e-07
# [1] "PP abf for shared variant: 5.9e-05%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#  3.38e-70  6.35e-06  1.84e-65  3.45e-01  6.55e-01
# [1] "PP abf for shared variant: 65.5%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#  1.45e-05  3.25e-06  7.84e-01  1.76e-01  3.96e-02
# [1] "PP abf for shared variant: 3.96%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#  3.65e-22  7.61e-01  1.06e-22  2.22e-01  1.73e-02
# [1] "PP abf for shared variant: 1.73%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#  1.99e-12  1.84e-05  1.09e-07  1.00e+00  5.95e-07
# [1] "PP abf for shared variant: 5.95e-05%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#    0.7740    0.0650    0.1380    0.0115    0.0120
# [1] "PP abf for shared variant: 1.2%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#  2.97e-38  1.61e-23  1.84e-15  1.00e+00  9.25e-17
# [1] "PP abf for shared variant: 9.25e-15%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#  1.22e-23  3.25e-24  7.56e-01  2.02e-01  4.20e-02
# [1] "PP abf for shared variant: 4.2%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#  7.06e-24  8.49e-24  4.39e-01  5.28e-01  3.23e-02
# [1] "PP abf for shared variant: 3.23%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#  2.86e-08  7.65e-01  8.09e-09  2.16e-01  1.95e-02
# [1] "PP abf for shared variant: 1.95%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#  0.002050  0.763000  0.000578  0.215000  0.019000
# [1] "PP abf for shared variant: 1.9%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#   0.00322   0.76200   0.00091   0.21500   0.01900
# [1] "PP abf for shared variant: 1.9%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#   0.73300   0.06790   0.17400   0.01610   0.00865
# [1] "PP abf for shared variant: 0.865%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#    0.6360    0.1450    0.1620    0.0370    0.0203
# [1] "PP abf for shared variant: 2.03%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#   0.69900   0.09010   0.17800   0.02300   0.00958
# [1] "PP abf for shared variant: 0.958%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#  1.35e-23  3.45e-24  7.82e-01  1.99e-01  1.88e-02
# [1] "PP abf for shared variant: 1.88%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#  1.26e-23  4.53e-24  7.24e-01  2.59e-01  1.65e-02
# [1] "PP abf for shared variant: 1.65%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#  1.27e-23  3.25e-24  7.81e-01  2.01e-01  1.89e-02
# [1] "PP abf for shared variant: 1.89%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#   0.76600   0.05850   0.15600   0.01190   0.00815
# [1] "PP abf for shared variant: 0.815%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#  5.65e-32  1.61e-23  3.52e-09  1.00e+00  1.20e-10
# [1] "PP abf for shared variant: 1.2e-08%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#  1.28e-89  2.41e-25  7.99e-67  1.40e-02  9.86e-01
# [1] "PP abf for shared variant: 98.6%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#  1.38e-23  3.11e-24  8.01e-01  1.80e-01  1.88e-02
# [1] "PP abf for shared variant: 1.88%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#  3.66e-22  7.65e-01  1.03e-22  2.15e-01  2.00e-02
# [1] "PP abf for shared variant: 2%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#  1.74e-30  1.61e-23  1.09e-07  1.00e+00  2.38e-09
# [1] "PP abf for shared variant: 2.38e-07%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#    0.7560    0.0634    0.1550    0.0130    0.0134
# [1] "PP abf for shared variant: 1.34%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#  1.58e-08  1.60e-05  9.84e-04  9.99e-01  2.75e-04
# [1] "PP abf for shared variant: 0.0275%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#  7.44e-06  7.09e-06  4.63e-01  4.42e-01  9.49e-02
# [1] "PP abf for shared variant: 9.49%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#  7.81e-06  8.03e-06  4.86e-01  5.00e-01  1.34e-02
# [1] "PP abf for shared variant: 1.34%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#  4.36e-06  9.98e-06  2.71e-01  6.21e-01  1.07e-01
# [1] "PP abf for shared variant: 10.7%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#  6.19e-19  1.61e-05  3.86e-14  1.00e+00  1.68e-05
# [1] "PP abf for shared variant: 0.00168%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#  7.35e-09  1.60e-05  4.58e-04  9.99e-01  3.47e-05
# [1] "PP abf for shared variant: 0.00347%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#  3.63e-44  1.61e-05  2.26e-39  1.00e+00  7.94e-07
# [1] "PP abf for shared variant: 7.94e-05%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#  4.89e-08  1.60e-05  3.04e-03  9.97e-01  5.53e-05
# [1] "PP abf for shared variant: 0.00553%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#  1.33e-05  2.52e-06  8.27e-01  1.57e-01  1.63e-02
# [1] "PP abf for shared variant: 1.63%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#  1.46e-05  1.13e-06  9.10e-01  7.05e-02  1.93e-02
# [1] "PP abf for shared variant: 1.93%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#  2.83e-10  1.61e-05  1.76e-05  1.00e+00  1.99e-06
# [1] "PP abf for shared variant: 0.000199%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#  1.92e-19  1.61e-05  1.19e-14  1.00e+00  6.39e-07
# [1] "PP abf for shared variant: 6.39e-05%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#  2.08e-43  1.61e-05  1.30e-38  1.00e+00  6.39e-07
# [1] "PP abf for shared variant: 6.39e-05%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#  7.95e-11  1.61e-05  4.95e-06  1.00e+00  1.06e-06
# [1] "PP abf for shared variant: 0.000106%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#  2.35e-13  1.61e-05  1.46e-08  1.00e+00  6.39e-07
# [1] "PP abf for shared variant: 6.39e-05%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#  4.00e-16  2.67e-07  2.49e-11  1.56e-02  9.84e-01
# [1] "PP abf for shared variant: 98.4%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#  4.79e-06  1.34e-05  2.62e-01  7.29e-01  9.41e-03
# [1] "PP abf for shared variant: 0.941%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#   0.39700   0.00258   0.58600   0.00380   0.01050
# [1] "PP abf for shared variant: 1.05%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#    0.1850    0.2050    0.2800    0.3100    0.0196
# [1] "PP abf for shared variant: 1.96%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#   0.37900   0.00911   0.57200   0.01370   0.02570
# [1] "PP abf for shared variant: 2.57%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#   0.38900   0.00274   0.57400   0.00402   0.03020
# [1] "PP abf for shared variant: 3.02%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#    0.3740    0.0154    0.5650    0.0231    0.0222
# [1] "PP abf for shared variant: 2.22%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#    0.2870    0.1050    0.4330    0.1580    0.0176
# [1] "PP abf for shared variant: 1.76%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#    0.3340    0.0553    0.4950    0.0820    0.0333
# [1] "PP abf for shared variant: 3.33%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#   0.38600   0.00689   0.57300   0.01020   0.02350
# [1] "PP abf for shared variant: 2.35%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#     0.240     0.151     0.362     0.228     0.019
# [1] "PP abf for shared variant: 1.9%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#    0.3780    0.0130    0.5690    0.0195    0.0204
# [1] "PP abf for shared variant: 2.04%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#   0.39200   0.00398   0.58000   0.00587   0.01780
# [1] "PP abf for shared variant: 1.78%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#  2.51e-13  5.14e-06  4.88e-08  1.00e+00  1.59e-06
# [1] "PP abf for shared variant: 0.000159%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#  4.61e-06  4.03e-07  8.97e-01  7.84e-02  2.49e-02
# [1] "PP abf for shared variant: 2.49%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#  9.93e-01  2.93e-03  3.67e-03  1.06e-05  1.99e-04
# [1] "PP abf for shared variant: 0.0199%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#  9.93e-01  2.82e-03  3.74e-03  1.04e-05  1.93e-04
# [1] "PP abf for shared variant: 0.0193%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#  9.94e-01  2.41e-03  3.74e-03  8.89e-06  1.56e-04
# [1] "PP abf for shared variant: 0.0156%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#  1.46e-07  4.98e-06  2.85e-02  9.69e-01  2.33e-03
# [1] "PP abf for shared variant: 0.233%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#   0.39600   0.00315   0.58500   0.00464   0.01130
# [1] "PP abf for shared variant: 1.13%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#  8.26e-34  1.09e-08  1.61e-28  1.12e-03  9.99e-01
# [1] "PP abf for shared variant: 99.9%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#  2.57e-10  2.52e-01  7.46e-10  7.29e-01  1.88e-02
# [1] "PP abf for shared variant: 1.88%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#  9.95e-01  2.21e-03  2.49e-03  5.41e-06  1.38e-04
# [1] "PP abf for shared variant: 0.0138%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#  9.95e-01  2.42e-03  2.49e-03  5.90e-06  1.54e-04
# [1] "PP abf for shared variant: 0.0154%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#  9.92e-01  4.13e-03  3.36e-03  1.36e-05  3.84e-04
# [1] "PP abf for shared variant: 0.0384%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#  9.93e-01  2.94e-03  3.37e-03  9.75e-06  2.12e-04
# [1] "PP abf for shared variant: 0.0212%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#  9.93e-01  3.24e-03  3.37e-03  1.08e-05  2.15e-04
# [1] "PP abf for shared variant: 0.0215%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#  9.94e-01  2.51e-03  3.37e-03  8.38e-06  1.43e-04
# [1] "PP abf for shared variant: 0.0143%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#  9.94e-01  2.82e-03  3.37e-03  9.38e-06  1.80e-04
# [1] "PP abf for shared variant: 0.018%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#  3.61e-06  1.46e-06  7.02e-01  2.83e-01  1.46e-02
# [1] "PP abf for shared variant: 1.46%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#   0.38400   0.00727   0.57300   0.01080   0.02460
# [1] "PP abf for shared variant: 2.46%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#   0.40700   0.00191   0.57300   0.00267   0.01560
# [1] "PP abf for shared variant: 1.56%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#  3.56e-09  5.14e-06  6.92e-04  9.99e-01  1.21e-05
# [1] "PP abf for shared variant: 0.00121%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#  3.76e-06  1.33e-06  7.33e-01  2.59e-01  8.76e-03
# [1] "PP abf for shared variant: 0.876%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#    0.3770    0.0185    0.5570    0.0274    0.0209
# [1] "PP abf for shared variant: 2.09%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#  1.23e-09  5.14e-06  2.39e-04  1.00e+00  2.45e-06
# [1] "PP abf for shared variant: 0.000245%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#  3.28e-21  3.94e-01  4.96e-21  5.94e-01  1.20e-02
# [1] "PP abf for shared variant: 1.2%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#  8.73e-07  3.92e-01  1.32e-06  5.92e-01  1.56e-02
# [1] "PP abf for shared variant: 1.56%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#  2.03e-16  3.93e-01  3.05e-16  5.92e-01  1.56e-02
# [1] "PP abf for shared variant: 1.56%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
# 1.97e-110  5.14e-06 3.84e-105  1.00e+00  1.22e-04
# [1] "PP abf for shared variant: 0.0122%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
# 5.63e-141  3.94e-01 8.50e-141  5.94e-01  1.20e-02
# [1] "PP abf for shared variant: 1.2%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#  6.27e-08  5.07e-06  1.22e-02  9.87e-01  4.99e-04
# [1] "PP abf for shared variant: 0.0499%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#  4.47e-06  5.49e-07  8.71e-01  1.07e-01  2.25e-02
# [1] "PP abf for shared variant: 2.25%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#  9.95e-01  1.82e-03  3.31e-03  5.93e-06  1.19e-04
# [1] "PP abf for shared variant: 0.0119%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#  3.96e-06  1.08e-06  7.70e-01  2.10e-01  2.03e-02
# [1] "PP abf for shared variant: 2.03%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#  3.25e-12  5.14e-06  6.33e-07  1.00e+00  1.53e-07
# [1] "PP abf for shared variant: 1.53e-05%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#  1.11e-06  4.01e-06  2.15e-01  7.81e-01  4.00e-03
# [1] "PP abf for shared variant: 0.4%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#  4.47e-29  5.14e-06  8.69e-24  1.00e+00  1.17e-04
# [1] "PP abf for shared variant: 0.0117%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#  4.98e-41  3.94e-01  7.52e-41  5.94e-01  1.20e-02
# [1] "PP abf for shared variant: 1.2%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#   0.38000   0.00858   0.57300   0.01290   0.02570
# [1] "PP abf for shared variant: 2.57%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#  8.56e-08  5.05e-06  1.66e-02  9.83e-01  8.07e-04
# [1] "PP abf for shared variant: 0.0807%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#   0.38400   0.00633   0.56600   0.00927   0.03440
# [1] "PP abf for shared variant: 3.44%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#   0.38900   0.00457   0.57400   0.00671   0.02570
# [1] "PP abf for shared variant: 2.57%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#  9.94e-01  2.61e-03  2.77e-03  7.10e-06  1.61e-04
# [1] "PP abf for shared variant: 0.0161%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#  9.94e-01  2.75e-03  2.77e-03  7.48e-06  1.75e-04
# [1] "PP abf for shared variant: 0.0175%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#    0.3750    0.0103    0.5570    0.0153    0.0426
# [1] "PP abf for shared variant: 4.26%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#   0.37600   0.00814   0.55500   0.01200   0.04920
# [1] "PP abf for shared variant: 4.92%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#  1.76e-06  3.34e-06  3.42e-01  6.50e-01  7.78e-03
# [1] "PP abf for shared variant: 0.778%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#   0.38600   0.00397   0.56800   0.00580   0.03590
# [1] "PP abf for shared variant: 3.59%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#   0.37900   0.00473   0.55800   0.00690   0.05140
# [1] "PP abf for shared variant: 5.14%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#   0.38300   0.00429   0.56300   0.00627   0.04320
# [1] "PP abf for shared variant: 4.32%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#  9.89e-01  5.87e-03  4.66e-03  2.72e-05  4.32e-04
# [1] "PP abf for shared variant: 0.0432%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#  1.00e+00  2.23e-04  2.03e-04  3.43e-08  1.10e-05
# [1] "PP abf for shared variant: 0.0011%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#   0.39200   0.00505   0.57800   0.00743   0.01680
# [1] "PP abf for shared variant: 1.68%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#  1.90e-09  3.89e-01  2.87e-09  5.87e-01  2.48e-02
# [1] "PP abf for shared variant: 2.48%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#  8.10e-08  5.05e-06  1.58e-02  9.83e-01  1.03e-03
# [1] "PP abf for shared variant: 0.103%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#   0.38800   0.00468   0.57200   0.00688   0.02880
# [1] "PP abf for shared variant: 2.88%"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#    0.1330    0.2570    0.2000    0.3870    0.0238
# [1] "PP abf for shared variant: 2.38%"

# %%
head(coloc.res)
# Out:
#   nsnps PP.H0.abf    PP.H1.abf    PP.H2.abf    PP.H3.abf    PP.H4.abf
# 1 1957  1.059982e-27 1.404602e-09 1.701734e-19 0.2247247439 7.752753e-01
# 2 1955  3.474068e-13 6.289976e-09 5.522792e-05 0.9999293797 1.538613e-05
# 3 1959  5.281794e-09 7.306150e-10 8.396567e-01 0.1161030067 4.424028e-02
# 4  396  9.468381e-01 3.929650e-02 1.219508e-02 0.0005049655 1.165373e-03
# 5  396  9.672760e-01 1.940598e-02 1.245832e-02 0.0002493346 6.103839e-04
# 6 1911  2.573640e-58 6.228834e-09 4.131816e-50 0.9999999937 7.566164e-11
#   Gene            eQTL.Signal Eigengene Module.QTL
# 1 ENSG00000011021 1           ME_62_3   ME_62_3-1:10790946-12847590
# 2 ENSG00000011021 2           ME_62_3   ME_62_3-1:10790946-12847590
# 3 ENSG00000011021 3           ME_62_3   ME_62_3-1:10790946-12847590
# 4 ENSG00000054523 1           ME_62_3   ME_62_3-1:10790946-12847590
# 5 ENSG00000054523 2           ME_62_3   ME_62_3-1:10790946-12847590
# 6 ENSG00000083444 1           ME_62_3   ME_62_3-1:10790946-12847590

# %% [markdown]
# ## Colocalizing Loci

# %%
options(repr.plot.width=10, repr.plot.height=8)

coloc.res %>%
    dplyr::filter(PP.H3.abf + PP.H4.abf > 0.25) %>%
    dplyr::mutate(Coloc.Factor=PP.H4.abf / (PP.H3.abf + PP.H4.abf)) %>%
    dplyr::mutate(Rank=rank(-Coloc.Factor, ties.method="first")) %>%
    ggplot() +
    geom_point(aes(x=Rank, y=Coloc.Factor)) +
    geom_hline(aes(yintercept=0.7), lty=2, color="firebrick1") +
    xlab("Signal") + ylab("PP4 / (PP3 + PP4)") +
    ggplot_theme
# Out:
# plot without title

# %%
colocalizing <- coloc.res %>%
    dplyr::filter(PP.H3.abf + PP.H4.abf > 0.25) %>%
    dplyr::mutate(Coloc.Factor=PP.H4.abf / (PP.H3.abf + PP.H4.abf)) %>%
    dplyr::filter(Coloc.Factor > 0.7) %>%
    dplyr::arrange(desc(Coloc.Factor))

# %%
head(colocalizing)
# Out:
#   nsnps PP.H0.abf     PP.H1.abf     PP.H2.abf     PP.H3.abf PP.H4.abf
# 1 2268  5.806199e-196 2.803456e-103  2.071086e-96 0         1
# 2 2268  1.386873e-218 2.803456e-103 4.947011e-119 0         1
# 3 2265  3.747056e-119 2.803456e-103  1.336584e-19 0         1
# 4 2268  5.999961e-153 2.803456e-103  2.140202e-53 0         1
# 5 2317  5.278947e-170 2.803456e-103  1.883014e-70 0         1
# 6 2268  1.640296e-133 2.803456e-103  5.850979e-34 0         1
#   Gene            eQTL.Signal Eigengene Module.QTL
# 1 ENSG00000135404 1           ME_96_1   ME_96_1-12:54681479-56681478
# 2 ENSG00000135424 1           ME_96_1   ME_96_1-12:54681479-56681478
# 3 ENSG00000135437 1           ME_96_1   ME_96_1-12:54681479-56681478
# 4 ENSG00000135441 1           ME_96_1   ME_96_1-12:54681479-56681478
# 5 ENSG00000170439 1           ME_96_1   ME_96_1-12:54681479-56681478
# 6 ENSG00000258056 1           ME_96_1   ME_96_1-12:54681479-56681478
#   Coloc.Factor
# 1 1
# 2 1
# 3 1
# 4 1
# 5 1
# 6 1

# %% [markdown]
# There are 480 eGenes that colocalize with at least one module QTL.

# %%
length(unique(colocalizing$Gene))
# Out:
# [1] 328

# %%
length(unique(gsub("_[0-5]-", "-", colocalizing$Module.QTL)))
# Out:
# [1] 78

# %% [markdown]
# ## eGene Membership in Modules

# %%
modules <- read.csv("~/gains_team282/nikhil/expression/gene_expression/modules.csv")
rownames(modules) <- modules$Gene

# %%
egenes.in.module <- colocalizing %>%
    dplyr::mutate(Gene.Module = modules[Gene, "Module"]) %>%
    dplyr::mutate(Eigengene.Module = paste0("Module_", gsub("_[0-5]$", "", gsub("ME\\_", "", Eigengene)))) %>%
    dplyr::select(Module.QTL, Gene.Module, Eigengene.Module) %>%
    dplyr::group_by(Module.QTL) %>%
    dplyr::summarize(
        eGene.In.Module=any(Gene.Module == Eigengene.Module),
        eGene.Not.In.Module=any(Gene.Module != Eigengene.Module)
    )
head(egenes.in.module)
# Out:
#   Module.QTL                     eGene.In.Module eGene.Not.In.Module
# 1 ME_100_4-2:177546938-179584183 TRUE            FALSE
# 2 ME_101_1-1:24243590-26454176   TRUE             TRUE
# 3 ME_101_1-12:54985643-57100037  TRUE             TRUE
# 4 ME_101_2-1:24243590-26454176   TRUE             TRUE
# 5 ME_101_2-12:54985643-57100037  TRUE             TRUE
# 6 ME_101_3-12:54985643-57100037  TRUE             TRUE

# %%
sum(egenes.in.module$eGene.In.Module)
# Out:
# [1] 149

# %%
sum(egenes.in.module$eGene.Not.In.Module)
# Out:
# [1] 99

# %%
egenes.in.module %>%
    dplyr::filter(!eGene.In.Module)
# Out:
#    Module.QTL                    eGene.In.Module eGene.Not.In.Module
# 1  ME_47_1-3:100304904-102512523 FALSE           TRUE
# 2  ME_47_5-3:100304904-102512523 FALSE           TRUE
# 3  ME_63_4-11:46459981-48629440  FALSE           TRUE
# 4  ME_71_1-3:100304904-102512523 FALSE           TRUE
# 5  ME_77_3-6:87297302-89449572   FALSE           TRUE
# 6  ME_81_1-6:27091680-31806579   FALSE           TRUE
# 7  ME_81_4-6:27091680-31806579   FALSE           TRUE
# 8  ME_81_5-6:27091680-31806579   FALSE           TRUE
# 9  ME_84_3-6:28836283-33978544   FALSE           TRUE
# 10 ME_84_3-6:28836283-33995104   FALSE           TRUE
# 11 ME_84_4-6:28836283-33978544   FALSE           TRUE
# 12 ME_84_4-6:28836283-33995104   FALSE           TRUE
# 13 ME_84_5-6:28836283-33978544   FALSE           TRUE
# 14 ME_84_5-6:28836283-33995104   FALSE           TRUE
# 15 ME_92_2-6:29991224-32464002   FALSE           TRUE
# 16 ME_92_5-6:25189128-28307054   FALSE           TRUE
# 17 ME_94_4-3:47689679-50854451   FALSE           TRUE
# 18 ME_94_5-3:47689679-50854451   FALSE           TRUE
# 19 ME_97_4-6:28355878-31905730   FALSE           TRUE
# 20 ME_97_4-6:28558600-31905730   FALSE           TRUE

# %% [markdown]
# ## Colocalization Association Plots

# %%
geno <- fread("/nfs/users/nfs_n/nm18/gains_team282/nikhil/data/genotypes/eigengene_sva_ss_genotypes.raw", sep=" ", drop=2:6)
colnames(geno) <- gsub(":", "_", gsub("\\_.*", "", colnames(geno)))

geno <- as.data.frame(geno)
colnames(geno) <- gsub("X", "", colnames(geno))
rownames(geno) <- gsub("^GA", "", geno[, 1])
geno[, 1] <- NULL

# %%
module.egenes <- colocalizing %>%
    dplyr::mutate(eQTL=paste0(Gene, "-", eQTL.Signal)) %>%
    dplyr::select(eQTL, Module.QTL) %>%
    dplyr::group_by(Module.QTL) %>%
    dplyr::summarize(eQTL=paste0(eQTL, collapse=","))

module.egenes.map <- lapply(1:nrow(module.egenes), function(i) { unlist(strsplit(module.egenes$eQTL[i], ",")) })
names(module.egenes.map) <- module.egenes$Module.QTL

# %%
module.qtl = names(module.egenes.map)[33]
module.qtl
# Out:
# [1] "ME_21_3-7:64030933-66499596"

# %%
qtl.locus <- gsub("ME_.*_[0-5]+-", "", module.qtl)
assoc <- dplyr::bind_rows(
    module.qtl.loci[[qtl.locus]][[module.qtl]] %>%
        dplyr::select(snp, pos, p, qtl=module.qtl),
    do.call(rbind, cis.eqtl.loci[[qtl.locus]]) %>%
        dplyr::select(snp=SNP, pos=Position, p=P_Value, qtl=ID) %>%
        dplyr::filter(qtl %in% module.egenes.map[[module.qtl]])
) %>%
    dplyr::mutate(log10p=-log10(p))

# %%
snp.set <- unique(assoc$snp)
ld <- cor(geno[,snp.set], use="pairwise.complete.obs")

ld.info <- do.call(rbind, assoc %>%
    dplyr::group_by(qtl) %>%
    dplyr::slice_min(p, n=1, with_ties=F) %>%
    apply(., 1, function(x) {
        as.data.frame(ld[, x[1]]) %>%
            dplyr::select(ld=1) %>%
            dplyr::mutate(snp=rownames(.), qtl=x[4], ld=ld^2)
    })
)

# %%
module.egenes.map[[module.qtl]]
# Out:
# [1] "ENSG00000213462-1" "ENSG00000226002-1" "ENSG00000234585-1"
# [4] "ENSG00000146757-1" "ENSG00000106610-1"

# %%
options(repr.plot.width=8, repr.plot.height=8)

palette <- colorRampPalette(rev(RColorBrewer::brewer.pal(11, "Spectral")))

merge(assoc, ld.info, by=c("snp", "qtl")) %>%
    ggplot() +
    geom_point(aes(x=pos / 10^6, y=log10p, fill=ld), pch=21, size=3) +
    scale_fill_gradientn(colors=palette(100), limits=c(0, 1)) +
    xlab("Position (Mb)") + ylab(bquote("-log"[10]*"(p-value)")) +
    facet_grid(qtl ~ ., scales="free_y") +
    ggplot_theme +
    theme(legend.position="right", strip.text.y=element_text(size=8))
# Out:
# plot without title
