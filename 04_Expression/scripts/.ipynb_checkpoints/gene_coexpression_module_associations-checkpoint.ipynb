# %% [markdown]
# # Module Associations
#
# **Created**: 20 October 2021

# %% [markdown]
# ## Environment

# %%
rm(list=ls())

if (!require("UpSetR")) {
    install.packages("UpSetR")
}
# Out:
# Loading required package: UpSetR
#
# Warning message in library(package, lib.loc = lib.loc, character.only = TRUE, logical.return = TRUE, :
# “there is no package called ‘UpSetR’”

# %%
library(tidyverse)
library(RColorBrewer)
library(cowplot)
library(UpSetR)

setwd("~/eQTL_pQTL_Characterization/")

source("04_Expression/scripts/utils/ggplot_theme.R")
# Out:
# ── Attaching packages ───────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────── tidyverse 1.3.1 ──
#
# ✔ ggplot2 3.3.5     ✔ purrr   0.3.4
# ✔ tibble  3.1.5     ✔ dplyr   1.0.7
# ✔ tidyr   1.1.4     ✔ stringr 1.4.0
# ✔ readr   2.0.2     ✔ forcats 0.5.1
#
# ── Conflicts ──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()

# %% [markdown]
# ## Load Data

# %%
var.exp <- read.csv("~/gains_team282/nikhil/expression/gene_expression/variance.explained.csv")

est.cell.prop <- read.csv("~/gains_team282/nikhil/expression/gene_expression/estimates.eigengene.cell.proportion.association.csv", row.names=1)
est.xcell <- read.csv("~/gains_team282/nikhil/expression/gene_expression/estimates.eigengene.xcell.score.association.csv", row.names=1)
est.srsq <- read.csv("~/gains_team282/nikhil/expression/gene_expression/estimates.eigengene.srsq.association.csv", row.names=1)
est.outcome <- read.csv("~/gains_team282/nikhil/expression/gene_expression/estimates.eigengene.outcome.association.csv", row.names=1)
est.time.point <- read.csv("~/gains_team282/nikhil/expression/gene_expression/estimates.eigengene.time.point.association.csv", row.names=1)

# %% [markdown]
# ## Create Combined Dataset

# %%
association.tbl <- dplyr::bind_rows(
  est.cell.prop, 
  est.xcell,
  est.srsq,
  est.outcome,
  est.time.point
)
rownames(association.tbl) <- NULL

write.csv(association.tbl, "~/gains_team282/nikhil/expression/gene_expression/estimates.all.csv", row.names=FALSE)

# %% [markdown]
# ## Identify Shared Association Sets

# %%
print(
  association.tbl %>%
    dplyr::group_by(Association.Variable.Type) %>%
    dplyr::summarize(SD=sd(Statistic))
)
# Out:
# # A tibble: 5 × 2
#   Association.Variable.Type     SD
#   <chr>                      <dbl>
# 1 Cell Proportion           0.385
# 2 Outcome                   8.20
# 3 SRSq                      0.540
# 4 Time Point                0.0218
# 5 xCell Score               0.166

# %%
plot.data <- association.tbl %>%
  dplyr::filter(Association.Variable.Type != "Cell Proportion" | (Adjusted.P.Value < 0.05 & abs(Statistic) >= 0.385)) %>%
  dplyr::filter(Association.Variable.Type != "xCell Score" | (Adjusted.P.Value < 0.05 & abs(Statistic) >= 0.166)) %>%
  dplyr::filter(Association.Variable.Type != "SRSq" | (Adjusted.P.Value < 0.05 & abs(Statistic) >= 0.540)) %>%
  dplyr::filter(Association.Variable.Type != "Outcome" | (Adjusted.P.Value < 0.05 & abs(Statistic) >= 8.20)) %>%
  dplyr::filter(Association.Variable.Type != "Time Point" | (Adjusted.P.Value < 0.05 & abs(Statistic) >= 0.0218))

plot.data <- split(plot.data, plot.data$Association.Variable.Type) %>%
  lapply(., function(x) unique(x[,"Eigengene"]))

plot.data[["None"]] <- setdiff(var.exp$Module, unique(unlist(plot.data)))

svg("04_Expression/results/eigengene_association_overlap.svg", width=8, height=6)
upset(
  fromList(plot.data), order.by="freq", empty.intersections="on",
  matrix.color="royalblue4", main.bar.color="royalblue3", sets.bar.color="royalblue3",
  text.scale=2
)
dev.off()

options(repr.plot.width=8, repr.plot.height=6)
upset(
  fromList(plot.data), order.by="freq", empty.intersections="on",
  matrix.color="royalblue4", main.bar.color="royalblue3", sets.bar.color="royalblue3",
  text.scale=2
)
# Out:
# png
#   2
# plot without title

# %%
# Identify Module Association Sets
modules <- Reduce(union, plot.data)

module.association.mtx <- lapply(modules, function(module.name) {
  return(sapply(plot.data, function(set) module.name %in% set))
}) %>%
  do.call(rbind, .) %>%
  as.data.frame()
rownames(module.association.mtx) <- modules

module.association.mtx
# Out:
#        Cell Proportion Outcome SRSq  Time Point xCell Score None
# ME_5   TRUE             TRUE    TRUE  TRUE      TRUE        FALSE
# ME_74  TRUE             TRUE    TRUE  TRUE      TRUE        FALSE
# ME_62  TRUE             TRUE    TRUE  TRUE      TRUE        FALSE
# ME_45  TRUE             TRUE    TRUE  TRUE      TRUE        FALSE
# ME_32  TRUE             TRUE    TRUE FALSE      TRUE        FALSE
# ME_51  TRUE             TRUE    TRUE  TRUE      TRUE        FALSE
# ME_24  TRUE             TRUE    TRUE FALSE      TRUE        FALSE
# ME_76  TRUE             TRUE    TRUE FALSE      TRUE        FALSE
# ME_10  TRUE             TRUE    TRUE  TRUE      TRUE        FALSE
# ME_43  TRUE             TRUE    TRUE  TRUE      TRUE        FALSE
# ME_89  TRUE             TRUE    TRUE  TRUE      TRUE        FALSE
# ME_25  TRUE             TRUE    TRUE  TRUE      TRUE        FALSE
# ME_40  TRUE             TRUE    TRUE  TRUE      TRUE        FALSE
# ME_35  TRUE             TRUE    TRUE FALSE      TRUE        FALSE
# ME_17  TRUE             TRUE    TRUE  TRUE      TRUE        FALSE
# ME_83  TRUE             TRUE    TRUE  TRUE      TRUE        FALSE
# ME_79  TRUE             TRUE    TRUE FALSE      TRUE        FALSE
# ME_61  TRUE             TRUE    TRUE  TRUE      TRUE        FALSE
# ME_31  TRUE             TRUE    TRUE FALSE      TRUE        FALSE
# ME_12  TRUE             TRUE    TRUE  TRUE      TRUE        FALSE
# ME_9   TRUE             TRUE    TRUE  TRUE      TRUE        FALSE
# ME_63  TRUE             TRUE    TRUE FALSE      TRUE        FALSE
# ME_88  TRUE             TRUE    TRUE FALSE      TRUE        FALSE
# ME_28  TRUE             TRUE    TRUE  TRUE      TRUE        FALSE
# ME_16  TRUE             TRUE    TRUE  TRUE      TRUE        FALSE
# ME_26  TRUE             TRUE    TRUE  TRUE      TRUE        FALSE
# ME_71  TRUE            FALSE    TRUE FALSE      TRUE        FALSE
# ME_44  TRUE             TRUE    TRUE FALSE      TRUE        FALSE
# ME_55  TRUE            FALSE   FALSE FALSE      TRUE        FALSE
# ME_65  TRUE             TRUE    TRUE  TRUE      TRUE        FALSE
# ⋮      ⋮               ⋮       ⋮     ⋮          ⋮           ⋮
# ME_14  FALSE           FALSE   FALSE FALSE      TRUE        FALSE
# ME_20  FALSE           FALSE   FALSE FALSE      TRUE        FALSE
# ME_30  FALSE           FALSE   FALSE FALSE      TRUE        FALSE
# ME_4   FALSE           FALSE   FALSE FALSE      TRUE        FALSE
# ME_60  FALSE           FALSE   FALSE FALSE      TRUE        FALSE
# ME_37  FALSE           FALSE   FALSE FALSE      TRUE        FALSE
# ME_27  FALSE           FALSE   FALSE FALSE      TRUE        FALSE
# ME_97  FALSE           FALSE   FALSE FALSE      TRUE        FALSE
# ME_81  FALSE           FALSE   FALSE FALSE      TRUE        FALSE
# ME_100 FALSE           FALSE   FALSE FALSE      TRUE        FALSE
# ME_21  FALSE           FALSE   FALSE FALSE      TRUE        FALSE
# ME_70  FALSE           FALSE   FALSE FALSE      TRUE        FALSE
# ME_93  FALSE           FALSE   FALSE FALSE      TRUE        FALSE
# ME_46  FALSE           FALSE   FALSE FALSE      TRUE        FALSE
# ME_41  FALSE           FALSE   FALSE FALSE      TRUE        FALSE
# ME_19  FALSE           FALSE   FALSE FALSE      TRUE        FALSE
# ME_91  FALSE           FALSE   FALSE FALSE      TRUE        FALSE
# ME_82  FALSE           FALSE   FALSE FALSE      TRUE        FALSE
# ME_8   FALSE           FALSE   FALSE FALSE      TRUE        FALSE
# ME_34  FALSE           FALSE   FALSE FALSE      TRUE        FALSE
# ME_66  FALSE           FALSE   FALSE FALSE      TRUE        FALSE
# ME_73  FALSE           FALSE   FALSE FALSE      TRUE        FALSE
# ME_68  FALSE           FALSE   FALSE FALSE      TRUE        FALSE
# ME_33  FALSE           FALSE   FALSE FALSE      TRUE        FALSE
# ME_77  FALSE           FALSE   FALSE FALSE      TRUE        FALSE
# ME_98  FALSE           FALSE   FALSE FALSE      TRUE        FALSE
# ME_47  FALSE           FALSE   FALSE FALSE      TRUE        FALSE
# ME_96  FALSE           FALSE   FALSE FALSE      TRUE        FALSE
# ME_59  FALSE           FALSE   FALSE FALSE      TRUE        FALSE
# ME_95  FALSE           FALSE   FALSE FALSE      TRUE        FALSE
